# %%
# !pip install yfinance
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)

# %%
#symbols = ["MSFT","AAPL","GOOG","TSLA","GGPI","BIM","AI","AMZN"]
symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]
dfs = []
for i in symbols:
   data = yf.download(i,period="MAX",interval="1mo")
   dfs.append(data)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
fixed_dfs = []
for df in dfs:
    full = []
    df = np.array(df)
    for i in range(15, df.shape[0]-1):
        fifteen_days_ago = i-15
        fourteen_days_ago = i-14
        thirteen_days_ago = i-13
        twelve_days_ago = i-12
        eleven_days_ago = i-11
        ten_days_ago = i-10
        nine_days_ago = i-9
        eight_days_ago = i-8
        seven_days_ago = i-7
        six_days_ago = i-6
        five_days_ago = i-5
        four_days_ago = i-4
        three_days_ago = i-3
        two_days_ago = i - 2
        yesterday = i - 1
        today = i
        tomorrow = i + 1
        if df[tomorrow][3] > df[today][3]:
            future = 1
        else:
            future = 0


        new_lst = [df[fifteen_days_ago][3],df[fourteen_days_ago][3],df[thirteen_days_ago][3],df[twelve_days_ago][3],df[eleven_days_ago][3],
                   df[ten_days_ago][3], df[nine_days_ago][3], df[eight_days_ago][3], df[seven_days_ago][3], df[six_days_ago][3],
                   df[five_days_ago][3], df[four_days_ago][3], df[three_days_ago][3], df[two_days_ago][3], df[yesterday][3],
                   df[today][3], future]

        full.append(new_lst)


    fuu = np.array([full])
    lst = []
    for i in range(0, fuu.shape[1]):
        lst.append(fuu[0][i])
    
    mm = np.array(lst)


    column_names = ["fifteen_days_ago","fourteen_days_ago","thirteen_days_ago","twelve_days_ago","eleven_days_ago",
                      "ten_days_ago", "nine_days_ago", "eight_days_ago", "seven_days_ago", "six_days_ago",
                       "five_days_ago", "four_days_ago", "three_days_ago", "two_days_ago", "yesterday", 
                        "today", "result"]
    
    cnwr = ["fifteen_days_ago","fourteen_days_ago","thirteen_days_ago","twelve_days_ago","eleven_days_ago",
                      "ten_days_ago", "nine_days_ago", "eight_days_ago", "seven_days_ago", "six_days_ago",
                       "five_days_ago", "four_days_ago", "three_days_ago", "two_days_ago", "yesterday", 
                        "today"]
    dff = pd.DataFrame(mm, columns=column_names)
    
    scaler = MinMaxScaler()
    xx = dff["result"]
    dff = dff.drop(["result"],axis=1)
    scaled = pd.DataFrame(scaler.fit_transform(dff.T).T, columns=cnwr)

    scaled["result"] = xx
       
    fixed_dfs.append(scaled)

data = fixed_dfs[0]
for i in range(1,len(symbols)):
  data = pd.concat([data,fixed_dfs[i]], ignore_index = True)
data = data.dropna()
data['rrsult']=data['result'].apply(lambda x: 'buy' if x==1.0 else 'sell')
xx = pd.get_dummies(data["rrsult"])
data = pd.concat([data,xx],axis=1)
X = data.drop(["result","rrsult","buy","sell"],axis=1)
y = data["sell"]
y2 = data["buy"]
y = pd.concat([y,y2],axis=1)
xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1,random_state=11)
print(xTrain.shape)
print(yTrain.shape)
print(xTest.shape)
print(yTest.shape)
# Out:
# (708, 16)
# (708, 2)
# (79, 16)
# (79, 2)

# %%
data
# Out:
#      fifteen_days_ago  fourteen_days_ago  thirteen_days_ago  twelve_days_ago  \
# 0            0.567130           0.753546           0.482063         0.000000
# 1            0.729151           0.466456           0.000000         0.167091
# 2            0.466456           0.000000           0.167091         0.121508
# 3            0.000000           0.159404           0.115917         0.080921
# 4            0.080334           0.047018           0.020207         0.000445
# ..                ...                ...                ...              ...
# 782          0.000000           0.057958           0.068729         0.154335
# 783          0.000000           0.011433           0.102306         0.039673
# 784          0.000000           0.091924           0.028566         0.302130
# 785          0.065221           0.000000           0.281608         0.380826
# 786          0.000000           0.281608           0.380826         1.000000
#
#      eleven_days_ago  ten_days_ago  nine_days_ago  eight_days_ago  \
# 0           0.172682      0.125573       0.087662        0.059718
# 1           0.121508      0.084824       0.057784        0.207090
# 2           0.084824      0.057784       0.207090        0.305068
# 3           0.055126      0.197562       0.291032        0.054545
# 4           0.109568      0.181177       0.000000        0.019925
# ..               ...           ...            ...             ...
# 782         0.095332      0.350094       0.439853        1.000000
# 783         0.310109      0.405390       1.000000        0.495962
# 784         0.398513      1.000000       0.490132        0.316778
# 785         1.000000      0.475139       0.296687        0.359756
# 786         0.475139      0.296687       0.359756        0.521889
#
#      seven_days_ago  six_days_ago  five_days_ago  four_days_ago  \
# 0          0.214019      0.315275       0.059089       0.087263
# 1          0.305068      0.057176       0.084438       0.439089
# 2          0.057176      0.084438       0.439089       0.725854
# 3          0.080553      0.418888       0.692459       0.923107
# 4          0.279129      0.488717       0.665420       0.460329
# ..              ...           ...            ...            ...
# 782        0.525175      0.363735       0.420792       0.567469
# 783        0.324590      0.385156       0.540858       0.421205
# 784        0.378045      0.535547       0.414511       0.492828
# 785        0.521889      0.397294       0.477914       0.352451
# 786        0.397294      0.477914       0.352451       0.319784
#
#      three_days_ago  two_days_ago  yesterday     today  result rrsult  buy  \
# 0          0.453781      0.750140   1.000000  0.709999     1.0    buy    1
# 1          0.725854      0.967625   0.687013  1.000000     0.0   sell    0
# 2          0.967625      0.687013   1.000000  0.904792     1.0    buy    1
# 3          0.655406      0.953993   0.863165  1.000000     1.0    buy    1
# 4          0.689082      0.619497   0.724329  1.000000     1.0    buy    1
# ..              ...           ...        ...       ...     ...    ...  ...
# 782        0.454751      0.527685   0.414183  0.384630     0.0   sell    0
# 783        0.498627      0.378142   0.346770  0.071187     1.0    buy    1
# 784        0.370950      0.339215   0.060444  0.138533     1.0    buy    1
# 785        0.319784      0.032815   0.113200  0.262972     1.0    buy    1
# 786        0.032815      0.113200   0.262972  0.278547     1.0    buy    1
#
#      sell
# 0       0
# 1       1
# 2       0
# 3       0
# 4       0
# ..    ...
# 782     1
# 783     0
# 784     0
# 785     0
# 786     0
#
# [787 rows x 20 columns]

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(xTrain,yTrain)
print(f"Random Forest :  {clf.score(xTest,yTest)}")
#logisticRegr = LogisticRegression()
#logisticRegr.fit(xTrain, yTrain)
#print(f"Logistic Regression: {logisticRegr.score(xTest, yTest)}")
#nc = NearestCentroid()
#nc.fit(xTrain,yTrain)
#print(f"Nearest Centroid: {nc.score(xTest,yTest)}")
#gnb = GaussianNB()
#gnb.fit(xTrain, yTrain)
#print(f"GaussianNB: {gnb.score(xTest,yTest)}")
clf2 = KNeighborsClassifier(n_neighbors=2)
clf2.fit(xTrain, yTrain)
print(f"K-Neighbors: {clf2.score(xTest,yTest)}")
tree = DecisionTreeClassifier()
tree.fit(xTrain, yTrain)
print(f"Decision Tree: {tree.score(xTest,yTest)}")
#gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
#   max_depth=1, random_state=0).fit(xTrain, yTrain)
#gb.fit(xTrain,yTrain)
#print(f"Gradient Boost: {gb.score(xTest, yTest)}")
#svm = SVC()
#svm.fit(xTrain,yTrain)
#print(f"SVM: {svm.score(xTest,yTest)}")
# Out:
# Random Forest :  0.6582278481012658
# K-Neighbors: 0.45569620253164556
# Decision Tree: 0.5949367088607594

# %%
model = Sequential()
model.add(Dense(202, activation='relu', kernel_initializer='he_normal', input_shape=(16,)))
model.add(Dense(2, activation='sigmoid'))

model.compile(optimizer='adam', loss=tf.keras.losses.CategoricalCrossentropy(),metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_17 (Dense)            (None, 202)               3434
#
#  dense_18 (Dense)            (None, 2)                 406
#
# =================================================================
# Total params: 3,840
# Trainable params: 3,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=75,batch_size=2,validation_data=(xTest,yTest))
# Out:
# Epoch 1/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.7028 - accuracy: 0.5297 - val_loss: 0.6726 - val_accuracy: 0.5570
# Epoch 2/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6438 - accuracy: 0.6469 - val_loss: 0.6980 - val_accuracy: 0.5949
# Epoch 3/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6212 - accuracy: 0.6681 - val_loss: 0.6961 - val_accuracy: 0.5696
# Epoch 4/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6028 - accuracy: 0.6525 - val_loss: 0.6994 - val_accuracy: 0.6456
# Epoch 5/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5780 - accuracy: 0.6893 - val_loss: 0.7022 - val_accuracy: 0.5443
# Epoch 6/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5735 - accuracy: 0.7090 - val_loss: 0.7172 - val_accuracy: 0.5190
# Epoch 7/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5594 - accuracy: 0.7020 - val_loss: 0.6731 - val_accuracy: 0.5823
# Epoch 8/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5478 - accuracy: 0.7246 - val_loss: 0.6748 - val_accuracy: 0.6076
# Epoch 9/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5358 - accuracy: 0.7189 - val_loss: 0.6643 - val_accuracy: 0.6203
# Epoch 10/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7218 - val_loss: 0.6631 - val_accuracy: 0.5949
# Epoch 11/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5155 - accuracy: 0.7429 - val_loss: 0.6475 - val_accuracy: 0.6329
# Epoch 12/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5085 - accuracy: 0.7599 - val_loss: 0.6438 - val_accuracy: 0.6203
# Epoch 13/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.5007 - accuracy: 0.7613 - val_loss: 0.6581 - val_accuracy: 0.6203
# Epoch 14/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4851 - accuracy: 0.7669 - val_loss: 0.6417 - val_accuracy: 0.6076
# Epoch 15/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4743 - accuracy: 0.7740 - val_loss: 0.6605 - val_accuracy: 0.6456
# Epoch 16/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4645 - accuracy: 0.7881 - val_loss: 0.6669 - val_accuracy: 0.6329
# Epoch 17/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4623 - accuracy: 0.7881 - val_loss: 0.6409 - val_accuracy: 0.6709
# Epoch 18/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4548 - accuracy: 0.7952 - val_loss: 0.6683 - val_accuracy: 0.6329
# Epoch 19/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4488 - accuracy: 0.7825 - val_loss: 0.6912 - val_accuracy: 0.6582
# Epoch 20/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4338 - accuracy: 0.8079 - val_loss: 0.7165 - val_accuracy: 0.6582
# Epoch 21/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4374 - accuracy: 0.7952 - val_loss: 0.6510 - val_accuracy: 0.6835
# Epoch 22/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4230 - accuracy: 0.7966 - val_loss: 0.6507 - val_accuracy: 0.6582
# Epoch 23/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4261 - accuracy: 0.8178 - val_loss: 0.6621 - val_accuracy: 0.6582
# Epoch 24/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4091 - accuracy: 0.8220 - val_loss: 0.6403 - val_accuracy: 0.6835
# Epoch 25/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.4098 - accuracy: 0.8206 - val_loss: 0.6533 - val_accuracy: 0.6582
# Epoch 26/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3946 - accuracy: 0.8390 - val_loss: 0.6594 - val_accuracy: 0.6582
# Epoch 27/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3880 - accuracy: 0.8305 - val_loss: 0.6424 - val_accuracy: 0.6709
# Epoch 28/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3842 - accuracy: 0.8362 - val_loss: 0.6954 - val_accuracy: 0.6709
# Epoch 29/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3824 - accuracy: 0.8220 - val_loss: 0.6860 - val_accuracy: 0.6709
# Epoch 30/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3792 - accuracy: 0.8460 - val_loss: 0.6716 - val_accuracy: 0.6709
# Epoch 31/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3749 - accuracy: 0.8347 - val_loss: 0.6916 - val_accuracy: 0.6582
# Epoch 32/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3636 - accuracy: 0.8446 - val_loss: 0.7125 - val_accuracy: 0.6835
# Epoch 33/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3639 - accuracy: 0.8362 - val_loss: 0.6676 - val_accuracy: 0.7089
# Epoch 34/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3561 - accuracy: 0.8446 - val_loss: 0.6737 - val_accuracy: 0.6962
# Epoch 35/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3515 - accuracy: 0.8418 - val_loss: 0.6982 - val_accuracy: 0.6582
# Epoch 36/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3501 - accuracy: 0.8545 - val_loss: 0.7053 - val_accuracy: 0.6835
# Epoch 37/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3387 - accuracy: 0.8545 - val_loss: 0.7085 - val_accuracy: 0.6962
# Epoch 38/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3302 - accuracy: 0.8715 - val_loss: 0.7078 - val_accuracy: 0.6835
# Epoch 39/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3281 - accuracy: 0.8616 - val_loss: 0.7587 - val_accuracy: 0.6709
# Epoch 40/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3229 - accuracy: 0.8757 - val_loss: 0.7251 - val_accuracy: 0.6962
# Epoch 41/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3232 - accuracy: 0.8573 - val_loss: 0.6741 - val_accuracy: 0.7089
# Epoch 42/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3185 - accuracy: 0.8686 - val_loss: 0.7531 - val_accuracy: 0.6962
# Epoch 43/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3135 - accuracy: 0.8701 - val_loss: 0.6955 - val_accuracy: 0.7089
# Epoch 44/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3120 - accuracy: 0.8715 - val_loss: 0.6960 - val_accuracy: 0.7089
# Epoch 45/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3061 - accuracy: 0.8686 - val_loss: 0.7421 - val_accuracy: 0.7089
# Epoch 46/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.3034 - accuracy: 0.8757 - val_loss: 0.7536 - val_accuracy: 0.6835
# Epoch 47/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2949 - accuracy: 0.8884 - val_loss: 0.7630 - val_accuracy: 0.6709
# Epoch 48/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2885 - accuracy: 0.8856 - val_loss: 0.8053 - val_accuracy: 0.6456
# Epoch 49/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2864 - accuracy: 0.8856 - val_loss: 0.7204 - val_accuracy: 0.7089
# Epoch 50/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2866 - accuracy: 0.8799 - val_loss: 0.7539 - val_accuracy: 0.6962
# Epoch 51/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2876 - accuracy: 0.8856 - val_loss: 0.7806 - val_accuracy: 0.7089
# Epoch 52/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2787 - accuracy: 0.8799 - val_loss: 0.7385 - val_accuracy: 0.7215
# Epoch 53/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2723 - accuracy: 0.9011 - val_loss: 0.7713 - val_accuracy: 0.6709
# Epoch 54/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2705 - accuracy: 0.8955 - val_loss: 0.7479 - val_accuracy: 0.7089
# Epoch 55/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2682 - accuracy: 0.8856 - val_loss: 0.7822 - val_accuracy: 0.6962
# Epoch 56/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2638 - accuracy: 0.8941 - val_loss: 0.7356 - val_accuracy: 0.6709
# Epoch 57/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2660 - accuracy: 0.8884 - val_loss: 0.7226 - val_accuracy: 0.7342
# Epoch 58/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2592 - accuracy: 0.8941 - val_loss: 0.8821 - val_accuracy: 0.6962
# Epoch 59/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2559 - accuracy: 0.9054 - val_loss: 0.7651 - val_accuracy: 0.7089
# Epoch 60/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2503 - accuracy: 0.8983 - val_loss: 0.7621 - val_accuracy: 0.7089
# Epoch 61/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2498 - accuracy: 0.8983 - val_loss: 0.7658 - val_accuracy: 0.7089
# Epoch 62/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2446 - accuracy: 0.9110 - val_loss: 0.8173 - val_accuracy: 0.7342
# Epoch 63/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2408 - accuracy: 0.9082 - val_loss: 0.8500 - val_accuracy: 0.7215
# Epoch 64/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2421 - accuracy: 0.8969 - val_loss: 0.8087 - val_accuracy: 0.7089
# Epoch 65/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2361 - accuracy: 0.9068 - val_loss: 0.7873 - val_accuracy: 0.7468
# Epoch 66/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2375 - accuracy: 0.9096 - val_loss: 0.8277 - val_accuracy: 0.7089
# Epoch 67/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2314 - accuracy: 0.9054 - val_loss: 0.7908 - val_accuracy: 0.7595
# Epoch 68/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2257 - accuracy: 0.9124 - val_loss: 0.7809 - val_accuracy: 0.7215
# Epoch 69/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2290 - accuracy: 0.9068 - val_loss: 0.7995 - val_accuracy: 0.7089
# Epoch 70/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2307 - accuracy: 0.9068 - val_loss: 0.7939 - val_accuracy: 0.7215
# Epoch 71/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2183 - accuracy: 0.9195 - val_loss: 0.8443 - val_accuracy: 0.7215
# Epoch 72/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2127 - accuracy: 0.9237 - val_loss: 0.8034 - val_accuracy: 0.7342
# Epoch 73/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2197 - accuracy: 0.9167 - val_loss: 0.8786 - val_accuracy: 0.6835
# Epoch 74/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2163 - accuracy: 0.9209 - val_loss: 0.8470 - val_accuracy: 0.7215
# Epoch 75/75
# 354/354 [==============================] - 1s 2ms/step - loss: 0.2003 - accuracy: 0.9251 - val_loss: 0.9372 - val_accuracy: 0.7089

# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime
import random
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: yahooquery in /usr/local/lib/python3.7/dist-packages (2.2.15)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.64.0)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.3.5)
# Requirement already satisfied: requests-futures>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.0.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yahooquery) (1.15.0)
# Requirement already satisfied: requests>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from requests-futures>=1.0.0->yahooquery) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (1.24.3)

# %%
clmns = ['15 Open', '15 High', '15 Low', '15 Close', '15 Volume', '14 Open', '14 High', '14 Low', '14 Close', '14 Volume', '13 Open', '13 High', '13 Low', '13 Close', '13 Volume', '12 Open', '12 High', '12 Low', '12 Close', '12 Volume', '11 Open', '11 High', '11 Low', '11 Close', '11 Volume', '10 Open', '10 High', '10 Low', '10 Close', '10 Volume', '9 Open', '9 High', '9 Low', '9 Close', '9 Volume', '8 Open', '8 High', '8 Low', '8 Close', '8 Volume', '7 Open', '7 High', '7 Low', '7 Close', '7 Volume', '6 Open', '6 High', '6 Low', '6 Close', '6 Volume', '5 Open', '5 High', '5 Low', '5 Close', '5 Volume', '4 Open', '4 High', '4 Low', '4 Close', '4 Volume', '3 Open', '3 High', '3 Low', '3 Close', '3 Volume', '2 Open', '2 High', '2 Low', '2 Close', '2 Volume', '1 Open', '1 High', '1 Low', '1 Close', '1 Volume',"suggestion"]
clmnsws = ['15 Open', '15 High', '15 Low', '15 Close', '15 Volume', '14 Open', '14 High', '14 Low', '14 Close', '14 Volume', '13 Open', '13 High', '13 Low', '13 Close', '13 Volume', '12 Open', '12 High', '12 Low', '12 Close', '12 Volume', '11 Open', '11 High', '11 Low', '11 Close', '11 Volume', '10 Open', '10 High', '10 Low', '10 Close', '10 Volume', '9 Open', '9 High', '9 Low', '9 Close', '9 Volume', '8 Open', '8 High', '8 Low', '8 Close', '8 Volume', '7 Open', '7 High', '7 Low', '7 Close', '7 Volume', '6 Open', '6 High', '6 Low', '6 Close', '6 Volume', '5 Open', '5 High', '5 Low', '5 Close', '5 Volume', '4 Open', '4 High', '4 Low', '4 Close', '4 Volume', '3 Open', '3 High', '3 Low', '3 Close', '3 Volume', '2 Open', '2 High', '2 Low', '2 Close', '2 Volume', '1 Open', '1 High', '1 Low', '1 Close', '1 Volume']
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
   #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
   'all_cryptocurrencies_us','all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',]
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(15,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-15][0],
                df[each-15][1],
                df[each-15][2],
                df[each-15][3],
                df[each-15][4],
                df[each-14][0],
                df[each-14][1],
                df[each-14][2],
                df[each-14][3],
                df[each-14][4],
                df[each-13][0],
                df[each-13][1],
                df[each-13][2],
                df[each-13][3],
                df[each-13][4],
                df[each-12][0],
                df[each-12][1],
                df[each-12][2],
                df[each-12][3],
                df[each-12][4],
                df[each-11][0],
                df[each-11][1],
                df[each-11][2],
                df[each-11][3],
                df[each-11][4],
                df[each-10][0],
                df[each-10][1],
                df[each-10][2],
                df[each-10][3],
                df[each-10][4],
                df[each-9][0],
                df[each-9][1],
                df[each-9][2],
                df[each-9][3],
                df[each-9][4],
                df[each-8][0],
                df[each-8][1],
                df[each-8][2],
                df[each-8][3],
                df[each-8][4],
                df[each-7][0],
                df[each-7][1],
                df[each-7][2],
                df[each-7][3],
                df[each-7][4],
                df[each-6][0],
                df[each-6][1],
                df[each-6][2],
                df[each-6][3],
                df[each-6][4],
                df[each-5][0],
                df[each-5][1],
                df[each-5][2],
                df[each-5][3],
                df[each-5][4],
                df[each-4][0],
                df[each-4][1],
                df[each-4][2],
                df[each-4][3],
                df[each-4][4],
                df[each-3][0],
                df[each-3][1],
                df[each-3][2],
                df[each-3][3],
                df[each-3][4],
                df[each-2][0],
                df[each-2][1],
                df[each-2][2],
                df[each-2][3],
                df[each-2][4],
                df[each-1][0],
                df[each-1][2],
                df[each-1][1],
                df[each-1][3],
                df[each-1][4],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,10))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object,columns = clmnsws)
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled,columns = clmnsws)
  df_scaled["suggestion"] = last_column
  return df_scaled
def process(df): 
      df = df.dropna()
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df,columns = clmns)
      df = row_scaler(df)
      #df = column_scaler(df)
      return df

# %%
def get_data(symbols):
    unattached_dfs = []
    for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
              pass
           else:
               if data.shape[0] > 14:
                   unattached_dfs.append(process(data))
    symbols = []
    symbol = []
    data = []

    data = pd.concat(unattached_dfs)
    data = data.astype(float)

    xTrain, xTest, yTrain, yTest = spliting(data)
    print(data.shape)
    data.to_csv(f"{random.randint(1,1000)}.csv")
    data = []
    return xTrain, xTest, yTrain, yTest

#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]
symbols = read_syms_from_txt()
#symbols = get_crypto_syms()

pieces = 10
new_arrays = np.array_split(symbols, pieces)
for symbols in new_arrays:
   xTrain, xTest, yTrain, yTest= get_data(symbols)
# Out:
# 1 Failed download:
# - PIH: No data found, symbol may be delisted
#
# 1 Failed download:
# - PIHPP: No data found, symbol may be delisted
#
# 1 Failed download:
# - FCCY: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFK: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFKKR: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFKKU: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFKKW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACIA: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACAM: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACAMU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACAMW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACCP: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - XLRN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACLL: No data found, symbol may be delisted
#
# 1 Failed download:
# - ADMS: No data found, symbol may be delisted
#
# 1 Failed download:
# - ADRO: No data found, symbol may be delisted
#
# 1 Failed download:
# - AEGN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARPO: No data found, symbol may be delisted
#
# 1 Failed download:
# - AGFSW: No data found, symbol may be delisted
#
# 1 Failed download:
# - AIMT: No data found, symbol may be delisted
#
# 1 Failed download:
# - AIRTW: No data found, symbol may be delisted
#
# 1 Failed download:
# - AKCA: No data found, symbol may be delisted
#
# 1 Failed download:
# - AKER: No data found, symbol may be delisted
#
# 1 Failed download:
# - ALSK: No data found, symbol may be delisted
#
# 1 Failed download:
# - ALXN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ALTA: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMAG: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMTBB: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMRH: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMRHW: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMRB: No data found, symbol may be delisted
#
# 1 Failed download:
# - ASRVP: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMHC: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMHCU: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMHCW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANCN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDA: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDAR: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - APEX: No data found, symbol may be delisted
#
# 1 Failed download:
# - APXT: No data found, symbol may be delisted
#
# 1 Failed download:
# - APXTU: No data found, symbol may be delisted
#
# 1 Failed download:
# - APXTW: No data found, symbol may be delisted
#
# 1 Failed download:
# - APHA: No data found, symbol may be delisted
#
# 1 Failed download:
# - AACQU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARYB: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARYBU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARYBW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ASNA: No data found, symbol may be delisted
#
# 1 Failed download:
# - ASFI: No data found, symbol may be delisted
#
# 1 Failed download:
# - AFH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ATCXW: No data found, symbol may be delisted
#
# 1 Failed download:
# - EARS: No data found, symbol may be delisted
# (1073500, 75) (1073500,)
# (119278, 75) (119278,)
# (1192778, 76)
#
# 1 Failed download:
# - AAXN: No data found, symbol may be delisted
#
# 1 Failed download:
# - AXGT: No data found, symbol may be delisted
#
# 1 Failed download:
# - AZRX: No data found, symbol may be delisted
#
# 1 Failed download:
# - BCOM: No data found, symbol may be delisted
#
# 1 Failed download:
# - RILYH: No data found, symbol may be delisted
#
# 1 Failed download:
# - BOCH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ZTEST: No data found, symbol may be delisted
#
# 1 Failed download:
# - BFYT: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPA: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPAR: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - BASI: No data found, symbol may be delisted
#
# 1 Failed download:
# - BHTG: No data found, symbol may be delisted
#
# 1 Failed download:
# - BSTC: No data found, symbol may be delisted
#
# 1 Failed download:
# - BMCH: No data found, symbol may be delisted
#
# 1 Failed download:
# - WIFI: No data found, symbol may be delisted
#
# 1 Failed download:
# - BOKFL: No data found, symbol may be delisted
#
# 1 Failed download:
# - BPFH: No data found, symbol may be delisted
#
# 1 Failed download:
# - BBRX: No data found, symbol may be delisted
#
# 1 Failed download:
# - BDGE: No data found, symbol may be delisted
#
# 1 Failed download:
# - BPY: No data found, symbol may be delisted
#
# 1 Failed download:
# - BPYU: No data found, symbol may be delisted
#
# 1 Failed download:
# - BPYUP: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRKS: No data found, symbol may be delisted
#
# 1 Failed download:
# - BMTC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CGIX: No data found, symbol may be delisted
#
# 1 Failed download:
# - CSWCL: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPTA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPST: No data found, symbol may be delisted
#
# 1 Failed download:
# - CATM: No data found, symbol may be delisted
#
# 1 Failed download:
# - CATB: No data found, symbol may be delisted
#
# 1 Failed download:
# - APOP: No data found, symbol may be delisted
#
# 1 Failed download:
# - APOPW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLRBZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - CBMG: No data found, symbol may be delisted
#
# 1 Failed download:
# - CETXW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CETV: No data found, symbol may be delisted
#
# 1 Failed download:
# - CNBKA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CERC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CFFA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CFFAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CFFAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CHFS: No data found, symbol may be delisted
#
# 1 Failed download:
# - CBPO: No data found, symbol may be delisted
#
# 1 Failed download:
# - CCCL: No data found, symbol may be delisted
#
# 1 Failed download:
# - CCRC: No data found, symbol may be delisted
#
# 1 Failed download:
# - JRJC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CIIC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CIICU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CIICW: No data found, symbol may be delisted
# (1004496, 75) (1004496,)
# (111611, 75) (111611,)
# (1116107, 76)
#
# 1 Failed download:
# - CBLI: No data found, symbol may be delisted
#
# 1 Failed download:
# - CGRO: No data found, symbol may be delisted
#
# 1 Failed download:
# - CGROU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CGROW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLCT: No data found, symbol may be delisted
#
# 1 Failed download:
# - HHT: No data found, symbol may be delisted
#
# 1 Failed download:
# - CBSHP: No data found, symbol may be delisted
#
# 1 Failed download:
# - ESXB: No data found, symbol may be delisted
#
# 1 Failed download:
# - CFBI: No data found, symbol may be delisted
#
# 1 Failed download:
# - CDOR: No data found, symbol may be delisted
#
# 1 Failed download:
# - CNST: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPTI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CORE: No data found, symbol may be delisted
#
# 1 Failed download:
# - CSOD: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLDB: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPAH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ICBK: No data found, symbol may be delisted
#
# 1 Failed download:
# - COWNZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - BREW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CREE: No data found, symbol may be delisted
#
# 1 Failed download:
# - CRSA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CRSAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CRSAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - DRIOW: No data found, symbol may be delisted
#
# 1 Failed download:
# - DFHTU: No data found, symbol may be delisted
#
# 1 Failed download:
# - DBCP: No data found, symbol may be delisted
#
# 1 Failed download:
# - DMPI: No data found, symbol may be delisted
#
# 1 Failed download:
# - DRMT: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - DFPH: No data found, symbol may be delisted
#
# 1 Failed download:
# - DFPHU: No data found, symbol may be delisted
#
# 1 Failed download:
# - DFPHW: No data found, symbol may be delisted
#
# 1 Failed download:
# - DPHC: No data found, symbol may be delisted
#
# 1 Failed download:
# - DPHCU: No data found, symbol may be delisted
#
# 1 Failed download:
# - DPHCW: No data found, symbol may be delisted
#
# 1 Failed download:
# - DRNA: No data found, symbol may be delisted
#
# 1 Failed download:
# - DRAD: No data found, symbol may be delisted
#
# 1 Failed download:
# - DRADP: No data found, symbol may be delisted
#
# 1 Failed download:
# - DLPNW: No data found, symbol may be delisted
#
# 1 Failed download:
# - DSPG: No data found, symbol may be delisted
#
# 1 Failed download:
# - DNKN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ETFC: No data found, symbol may be delisted
#
# 1 Failed download:
# - IGLE: No data found, symbol may be delisted
#
# 1 Failed download:
# - ESSCR: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - ECHO: No data found, symbol may be delisted
#
# 1 Failed download:
# - EDNT: No data found, symbol may be delisted
#
# 1 Failed download:
# - EIDX: No data found, symbol may be delisted
#
# 1 Failed download:
# - EIGI: No data found, symbol may be delisted
#
# 1 Failed download:
# - EVSI: No data found, symbol may be delisted
#
# 1 Failed download:
# - EVSIW: No data found, symbol may be delisted
#
# 1 Failed download:
# - EXFO: No data found, symbol may be delisted
#
# 1 Failed download:
# - EXPC: No data found, symbol may be delisted
#
# 1 Failed download:
# - EXPCU: No data found, symbol may be delisted
#
# 1 Failed download:
# - EXPCW: No data found, symbol may be delisted
# (1096026, 75) (1096026,)
# (121781, 75) (121781,)
# (1217807, 76)
#
# 1 Failed download:
# - STAY: No data found, symbol may be delisted
#
# 1 Failed download:
# - EYEG: No data found, symbol may be delisted
#
# 1 Failed download:
# - EYEGW: No data found, symbol may be delisted
#
# 1 Failed download:
# - FLRZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - FBSS: No data found, symbol may be delisted
#
# 1 Failed download:
# - FDUSG: No data found, symbol may be delisted
#
# 1 Failed download:
# - FDUSL: No data found, symbol may be delisted
#
# 1 Failed download:
# - FDUSZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - FSRV: No data found, symbol may be delisted
#
# 1 Failed download:
# - FSRVU: No data found, symbol may be delisted
#
# 1 Failed download:
# - FSRVW: No data found, symbol may be delisted
#
# 1 Failed download:
# - FTAC: No data found, symbol may be delisted
#
# 1 Failed download:
# - FTACU: No data found, symbol may be delisted
#
# 1 Failed download:
# - FTACW: No data found, symbol may be delisted
#
# 1 Failed download:
# - FEYE: No data found, symbol may be delisted
#
# 1 Failed download:
# - FCBP: No data found, symbol may be delisted
#
# 1 Failed download:
# - INBKL: No data found, symbol may be delisted
#
# 1 Failed download:
# - FPRX: No data found, symbol may be delisted
#
# 1 Failed download:
# - FVE: No data found, symbol may be delisted
#
# 1 Failed download:
# - FLXN: No data found, symbol may be delisted
#
# 1 Failed download:
# - FLIR: No data found, symbol may be delisted
#
# 1 Failed download:
# - FLWR: No data found, symbol may be delisted
#
# 1 Failed download:
# - FSCT: No data found, symbol may be delisted
#
# 1 Failed download:
# - FMCI: No data found, symbol may be delisted
#
# 1 Failed download:
# - FMCIU: No data found, symbol may be delisted
#
# 1 Failed download:
# - FMCIW: No data found, symbol may be delisted
#
# 1 Failed download:
# - FRAN: No data found, symbol may be delisted
#
# 1 Failed download:
# - FORK: No data found, symbol may be delisted
#
# 1 Failed download:
# - FMAX: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - GARS: No data found, symbol may be delisted
#
# 1 Failed download:
# - GLIBA: No data found, symbol may be delisted
#
# 1 Failed download:
# - GFN: No data found, symbol may be delisted
#
# 1 Failed download:
# - GFNCP: No data found, symbol may be delisted
#
# 1 Failed download:
# - GFNSL: No data found, symbol may be delisted
#
# 1 Failed download:
# - GNMK: No data found, symbol may be delisted
#
# 1 Failed download:
# - GLADL: No data found, symbol may be delisted
#
# 1 Failed download:
# - GOODM: No data found, symbol may be delisted
#
# 1 Failed download:
# - GAINL: No data found, symbol may be delisted
#
# 1 Failed download:
# - LANDP: No data found, symbol may be delisted
#
# 1 Failed download:
# - ENT: No data found, symbol may be delisted
#
# 1 Failed download:
# - GBLIL: No data found, symbol may be delisted
#
# 1 Failed download:
# - GBLIZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - GLUU: No data found, symbol may be delisted
#
# 1 Failed download:
# - GMLP: No data found, symbol may be delisted
#
# 1 Failed download:
# - GMLPP: No data found, symbol may be delisted
#
# 1 Failed download:
# - DNJR: No data found, symbol may be delisted
#
# 1 Failed download:
# - GBLK: No data found, symbol may be delisted
# (890390, 75) (890390,)
# (98933, 75) (98933,)
# (989323, 76)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c044854f2872> in <module>()
#      32 new_arrays = np.array_split(symbols, pieces)
#      33 for symbols in new_arrays:
# ---> 34    xTrain, xTest, yTrain, yTest= get_data(symbols)
#      35
#
# <ipython-input-8-c044854f2872> in get_data(symbols)
#      17     xTrain, xTest, yTrain, yTest = spliting(data)
#      18     print(data.shape)
# ---> 19     data.to_csv(f"{random.randint(1,1000)}.parquet")
#      20     data = []
#      21     return xTrain, xTest, yTrain, yTest
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3480             doublequote=doublequote,
#    3481             escapechar=escapechar,
# -> 3482             storage_options=storage_options,
#    3483         )
#    3484
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/csvs.py in save(self)
#     255             )
#     256
# --> 257             self._save()
#     258
#     259     def _save(self) -> None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/csvs.py in _save(self)
#     260         if self._need_to_save_header:
#     261             self._save_header()
# --> 262         self._save_body()
#     263
#     264     def _save_header(self) -> None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/csvs.py in _save_body(self)
#     298             if start_i >= end_i:
#     299                 break
# --> 300             self._save_chunk(start_i, end_i)
#     301
#     302     def _save_chunk(self, start_i: int, end_i: int) -> None:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/formats/csvs.py in _save_chunk(self, start_i, end_i)
#     314             self.nlevels,
#     315             self.cols,
# --> 316             self.writer,
#     317         )
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/writers.pyx in pandas._libs.writers.write_csv_rows()
#
# KeyboardInterrupt:

# %%
data = pd.concat([pd.read_csv("327.parquet"),pd.read_csv("338.parquet"),pd.read_csv("417.parquet"),pd.read_csv("780.parquet")])
data = data.drop("Unnamed: 0",axis=1)
xTrain, xTest, yTrain, yTest = spliting(data)
data
# Out:
# (3486825, 75) (3486825,)
# (387426, 75) (387426,)
#           15 Open   15 High    15 Low  15 Close  15 Volume   14 Open  \
# 0        0.486723  0.705721  0.322475  0.418286   0.418286  0.418286
# 1        0.418286  0.506159  0.221188  0.392007   0.392007  0.401862
# 2        0.401862  0.596222  0.377772  0.552423   0.552423  0.607720
# 3        0.607720  0.864495  0.564632  0.638927   0.638927  0.642759
# 4        0.642759  0.939502  0.577060  0.924719   0.924719  0.969067
# ...           ...       ...       ...       ...        ...       ...
# 1217802  0.840094  0.929798  0.726209  0.922777   0.922777  0.854135
# 1217803  0.854135  1.000000  0.796412  0.872855   0.872855  0.890796
# 1217804  0.907790  0.963434  0.863275  0.917329   0.917329  0.918124
# 1217805  0.918124  0.920509  0.582671  0.589825   0.589825  0.628776
# 1217806  0.628776  0.722576  0.596184  0.709062   0.709062  0.724960
#
#           14 High    14 Low  14 Close  14 Volume  ...    2 High     2 Low  \
# 0        0.506159  0.221188  0.392007   0.392007  ...  0.372844  0.048727
# 1        0.596222  0.377772  0.552423   0.552423  ...  0.116069  0.000000
# 2        0.864495  0.564632  0.638927   0.638927  ...  0.171366  0.035040
# 3        0.939502  0.577060  0.924719   0.924719  ...  0.450589  0.148371
# 4        1.000000  0.871612  0.876540   0.876540  ...  0.444019  0.214618
# ...           ...       ...       ...        ...  ...       ...       ...
# 1217802  1.000000  0.796412  0.872855   0.872855  ...  0.208269  0.046802
# 1217803  0.945398  0.847114  0.900156   0.900156  ...  0.232450  0.000000
# 1217804  0.920509  0.582671  0.589825   0.589825  ...  0.281399  0.150238
# 1217805  0.722576  0.596184  0.709062   0.709062  ...  0.314786  0.126391
# 1217806  0.738474  0.536566  0.632751   0.632751  ...  0.362480  0.119237
#
#           2 Close  2 Volume    1 Open    1 High     1 Low   1 Close  1 Volume  \
# 0        0.105119  0.105119  0.091432  0.000000  0.116069  0.052559  0.052559
# 1        0.052559  0.052559  0.090884  0.035040  0.171366  0.164796  0.164796
# 2        0.164796  0.164796  0.158226  0.148371  0.450589  0.347112  0.347112
# 3        0.347112  0.347112  0.382699  0.214618  0.444019  0.287435  0.287435
# 4        0.287435  0.287435  0.267725  0.212976  0.337257  0.243088  0.243088
# ...           ...       ...       ...       ...       ...       ...       ...
# 1217802  0.108424  0.108424  0.104524  0.000000  0.232450  0.216069  0.216069
# 1217803  0.216069  0.216069  0.237910  0.147426  0.276131  0.225429  0.225429
# 1217804  0.229730  0.229730  0.206678  0.126391  0.314786  0.156598  0.156598
# 1217805  0.156598  0.156598  0.190779  0.119237  0.362480  0.142289  0.142289
# 1217806  0.142289  0.142289  0.164547  0.125596  0.240859  0.192369  0.192369
#
#          suggestion
# 0               1.0
# 1               1.0
# 2               0.0
# 3               0.0
# 4               1.0
# ...             ...
# 1217802         0.0
# 1217803         0.0
# 1217804         0.0
# 1217805         1.0
# 1217806         0.0
#
# [3874251 rows x 76 columns]

# %%
model = Sequential()



model.add(Dense(4096, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(3096, activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(1024, activation='relu'))
model.add(Dense(1024, activation='relu'))

model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 4096)              311296
#
#  dense_22 (Dense)            (None, 3096)              12684312
#
#  dense_23 (Dense)            (None, 2048)              6342656
#
#  dense_24 (Dense)            (None, 1024)              2098176
#
#  dense_25 (Dense)            (None, 1024)              1049600
#
#  dense_26 (Dense)            (None, 1)                 1025
#
# =================================================================
# Total params: 22,487,065
# Trainable params: 22,487,065
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=50,batch_size=10000,validation_data=(xTest,yTest))
# Out:
# Epoch 1/50
#   3/349 [..............................] - ETA: 1:52:01 - loss: 1.1180 - accuracy: 0.5078

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime

# %%
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
  #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
 'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in','all_cryptocurrencies_us']
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(13,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-12][3],
                df[each-11][3],
                df[each-10][3],
                df[each-9][3],
                df[each-8][3],
                df[each-7][3],
                df[each-6][3],
                df[each-5][3],
                df[each-4][3],
                df[each-3][3],
                df[each-2][3],
                df[each-1][3],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,5))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object,columns=["12_candels_close","11_candels_close","10_candels_close","9_candels_close","8_candels_close","7_candels_close", "6_candels_close","5_candels_close","4_candels_close","3_candels_close","2_candels_close","1_candels_close"])
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled, columns=["12_candels_close","11_candels_close","10_candels_close","9_candels_close","8_candels_close","7_candels_close", "6_candels_close","5_candels_close","4_candels_close","3_candels_close","2_candels_close","1_candels_close"])
  df_scaled["suggestion"] = last_column
  return df_scaled
def stick_dfs(dfs):
  dataframe = dfs[0]
  for i in range(1,len(dfs)):
     dataframe = pd.concat([dataframe,dfs[i]], ignore_index = True)
  dataframe = dataframe.dropna()
  dataframe = dataframe.astype(float)
  return dataframe
def process(dfs): 
   fixed_dfs = []
   for df in dfs:
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df,columns = ["12_candels_close","11_candels_close","10_candels_close","9_candels_close","8_candels_close","7_candels_close", "6_candels_close","5_candels_close","4_candels_close","3_candels_close","2_candels_close","1_candels_close","suggestion"])
      df = row_scaler(df)
      #df = column_scaler(df)
      fixed_dfs.append(df)
   df = stick_dfs(fixed_dfs)
   return df

# %%
#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]

#symbols = get_crypto_syms()
symbols = read_syms_from_txt()
dfs = []
for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
             print("Passing...")
           else:
               dfs.append(data)
ndfs = dfs
dfs = []
for df in ndfs:
        if df.shape[0] > 13:
          dfs.append(df)
data = process(dfs)
now = datetime.now()
current_time = now.strftime("%H%M%S")
data.to_csv(f"{current_time}.csv")
xTrain, xTest, yTrain, yTest = spliting(data)
data
# Out:
# 1 Failed download:
# - PIH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - PIHPP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FCCY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFKKR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFKKU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFKKW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACIA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACAM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACAMU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACAMW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACCP: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - XLRN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACLL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ADMS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ADRO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AEGN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARPO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AGBAR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AGFSW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AIMT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AIRTW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AKCA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AKER: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALSK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALACR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALXN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALTA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMAG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMTBB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMRH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMRHW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMRB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ASRVP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMHC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMHCU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMHCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANCN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDAR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APEX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APXT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APXTU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APXTW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APHA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AACQU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARYB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARYBU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARYBW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ASNA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ASFI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AFH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ATCXW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EARS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AAXN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AXGT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AZRX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BCOM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - RILYH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BOCH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZTEST: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BFYT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPAR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BASI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BHTG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BSTC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BMCH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WIFI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BOKFL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPFH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BBRX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BDGE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRLIR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPYU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPYUP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRKS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BMTC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGIX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CSWCL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPTA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPST: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CATM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CATB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APOP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APOPW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CLRBZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBMG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CETXW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CETV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CNBKA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CERC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFFA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFFAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFFAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CHFS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBPO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CCCL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CCRC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JRJC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CIIC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CIICU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CIICW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBLI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGRO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGROU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGROW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CLCT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HHT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBSHP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ESXB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFBI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CDOR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CNST: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPTI: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CORE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CSOD: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CLDB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPAH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ICBK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - COWNZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BREW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CREE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CRSA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CRSAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CRSAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRIOW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFHTU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DBCP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DMPI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRMT: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFPH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFPHU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFPHW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DPHC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DPHCU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DPHCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRNA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRAD: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRADP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DLPNW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DSPG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DNKN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ETFC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - IGLE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ESSCR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ECHO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EDNT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EIDX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EIGI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EVSI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EVSIW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXFO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXPC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXPCU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXPCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - STAY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EYEG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EYEGW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLRZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FBSS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FDUSG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FDUSL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FDUSZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSRV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSRVU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSRVW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FTAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FTACU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FTACW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FEYE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FCBP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - INBKL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FPRX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FVE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLXN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLIR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLWR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSCT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FMCI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FMCIU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FMCIW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FRAN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FORK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FMAX: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GARS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GLIBA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GFN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GFNCP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GFNSL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GNMK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GLADL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GOODM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GAINL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LANDP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ENT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GBLIL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GBLIZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GLUU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GMLP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GMLPP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DNJR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GBLK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GHIV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GHIVU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GHIVW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GMHI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GMHIU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GMHIW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GECCL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GECCM: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GEC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GRNV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GRNVR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GRNVU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GRNVW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GDYNW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GSUM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GRIF: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GWPH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GXGX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GXGXU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GXGXW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HJLI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HJLIW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HWCPL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCAP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCAPZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HDS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCCO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCCOU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCCOW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HEBT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCACU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCACW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MLHR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCCH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCCHR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCCHU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HCCHW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HMSY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HWCC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HBMD: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HEC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HECCU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HECCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HBANN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HBANO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ICON: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - IEC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - IKNX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ISNS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - IMMU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - INWK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - INOV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - INSU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - INSUU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - INSUW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - NTEC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - IPLDP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CMFNL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ITMR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JCOM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JMPNZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KBLM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KBLMR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KBLMU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KBLMW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KBSF: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KIN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KTOV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - KTOVW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LMRK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LMRKN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LMRKO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LMRKP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LACQ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LACQU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LACQW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LLIT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LSAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LSACU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LSACW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LIVK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LIVKU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LIVKW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LIVX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LVGO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LMFAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LOGM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LONE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LOAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LOACR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LOACU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LOACW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LORL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LMNX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MFNC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MAGS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MGLN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MJCO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MRLN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MXIM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MDCA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MFINL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MNLO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MTSL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MCMJ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MCMJW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EBSB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MCEP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MLND: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MGEN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MSON: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MMAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MWK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MNTA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MKGI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MNCL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MNCLU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MNCLW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MOSY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MCACU: No data found, symbol may be delisted
# Passing...

# %%
model = Sequential()
adam = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=True,
    name="Adam")


model.add(Dense(5000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(4096, activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(750, activation='relu'))
model.add(Dense(350, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer=adam, loss='binary_crossentropy',metrics=['accuracy'])
model.summary()

# %%
model.fit(xTrain,yTrain,epochs=111,batch_size=20000,validation_data=(xTest,yTest))
model.save(f"{model.evaluate(xTest,yTest)}.h5")

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(xTrain,yTrain)
print(f"Random Forest :  {clf.score(xTest,yTest)}")
logisticRegr = LogisticRegression()
logisticRegr.fit(xTrain, yTrain)
print(f"Logistic Regression: {logisticRegr.score(xTest, yTest)}")
nc = NearestCentroid()
nc.fit(xTrain,yTrain)
print(f"Nearest Centroid: {nc.score(xTest,yTest)}")
gnb = GaussianNB()
gnb.fit(xTrain, yTrain)
print(f"GaussianNB: {gnb.score(xTest,yTest)}")
clf2 = KNeighborsClassifier(n_neighbors=2)
clf2.fit(xTrain, yTrain)
print(f"K-Neighbors: {clf2.score(xTest,yTest)}")
tree = DecisionTreeClassifier()
tree.fit(xTrain, yTrain)
print(f"Decision Tree: {tree.score(xTest,yTest)}")
gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
   max_depth=1, random_state=0).fit(xTrain, yTrain)
gb.fit(xTrain,yTrain)
print(f"Gradient Boost: {gb.score(xTest, yTest)}")
svm = SVC()
svm.fit(xTrain,yTrain)
print(f"SVM: {svm.score(xTest,yTest)}")

# %%
import os
files = os.listdir("/content/gdrive/MyDrive/Colab Files/")

data = pd.DataFrame()
for file in files:
  address = f"/content/gdrive/MyDrive/Colab Files/{file}"
  df = pd.read_csv(address)
  data = pd.concat([data,df])

# %%
symbols = read_syms_from_txt()
len(symbols)
pieces = 15
new_arrays = np.array_split(symbols, pieces)
for i in new_arrays:
  dfs = []
  for x in i:
        data = yf.download(x,period="MAX",interval="1d",progress=False)
        if data.empty :
             print("Passing...")
        else:
               dfs.append(data)
  ndfs = dfs
  dfs = []
  for df in ndfs:
        if df.shape[0] > 12:
          dfs.append(df)
  data = process(dfs)
  data.to_csv(f"{x}.csv")

# %%
from google.colab import drive
drive.mount("/content/gdrive/")

# %%
address = "/content/gdrive/MyDrive/Colab Files/063821.csv"
data = pd.read_csv(address)

data

# %%
data = data.drop(["Unnamed: 0"],axis=1)
xTrain, xTest, yTrain, yTest = spliting(data)
data

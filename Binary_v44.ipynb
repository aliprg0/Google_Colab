# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime

# %%
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
  #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
 'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in','all_cryptocurrencies_us']
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(13,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-12][3],
                df[each-11][3],
                df[each-10][3],
                df[each-9][3],
                df[each-8][3],
                df[each-7][3],
                df[each-6][3],
                df[each-5][3],
                df[each-4][3],
                df[each-3][3],
                df[each-2][3],
                df[each-1][3],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,5))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object,columns=["12_candels_close","11_candels_close","10_candels_close","9_candels_close","8_candels_close","7_candels_close", "6_candels_close","5_candels_close","4_candels_close","3_candels_close","2_candels_close","1_candels_close"])
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled, columns=["12_candels_close","11_candels_close","10_candels_close","9_candels_close","8_candels_close","7_candels_close", "6_candels_close","5_candels_close","4_candels_close","3_candels_close","2_candels_close","1_candels_close"])
  df_scaled["suggestion"] = last_column
  return df_scaled
def stick_dfs(dfs):
  dataframe = dfs[0]
  for i in range(1,len(dfs)):
     dataframe = pd.concat([dataframe,dfs[i]], ignore_index = True)
  dataframe = dataframe.dropna()
  dataframe = dataframe.astype(float)
  return dataframe
def process(dfs): 
   fixed_dfs = []
   for df in dfs:
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df,columns = ["12_candels_close","11_candels_close","10_candels_close","9_candels_close","8_candels_close","7_candels_close", "6_candels_close","5_candels_close","4_candels_close","3_candels_close","2_candels_close","1_candels_close","suggestion"])
      df = row_scaler(df)
      #df = column_scaler(df)
      fixed_dfs.append(df)
   df = stick_dfs(fixed_dfs)
   return df

# %%
#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]

#symbols = get_crypto_syms()
symbols = read_syms_from_txt()
dfs = []
for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
             print("Passing...")
           else:
               dfs.append(data)
ndfs = dfs
dfs = []
for df in ndfs:
        if df.shape[0] > 13:
          dfs.append(df)
data = process(dfs)
now = datetime.now()
current_time = now.strftime("%H%M%S")
data.to_csv(f"{current_time}.csv")
xTrain, xTest, yTrain, yTest = spliting(data)
data
# Out:
# 1 Failed download:
# - PIH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - PIHPP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FCCY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFKKR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFKKU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JFKKW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACIA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACAM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACAMU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACAMW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACCP: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - XLRN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ACLL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ADMS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ADRO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AEGN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARPO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AGBAR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AGFSW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AIMT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AIRTW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AKCA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AKER: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALSK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALACR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALXN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ALTA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMAG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMTBB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMRH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMRHW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMRB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ASRVP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMHC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMHCU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AMHCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANCN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDAR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ANDAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APEX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APXT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APXTU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APXTW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APHA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AACQU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARYB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARYBU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ARYBW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ASNA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ASFI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AFH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ATCXW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EARS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AAXN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AXGT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - AZRX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BCOM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - RILYH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BOCH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZTEST: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BFYT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPAR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRPAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BASI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BHTG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BSTC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BMCH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WIFI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BOKFL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPFH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BBRX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BDGE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRLIR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPYU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BPYUP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BRKS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BMTC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGIX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CSWCL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPTA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPST: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CATM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CATB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APOP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - APOPW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CLRBZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBMG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CETXW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CETV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CNBKA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CERC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFFA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFFAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFFAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CHFS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBPO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CCCL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CCRC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - JRJC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CIIC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CIICU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CIICW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBLI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGRO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGROU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CGROW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CLCT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - HHT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CBSHP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ESXB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CFBI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CDOR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CNST: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPTI: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CORE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CSOD: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CLDB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CPAH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ICBK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - COWNZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BREW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CREE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CRSA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CRSAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CRSAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRIOW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFHTU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DBCP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DMPI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRMT: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFPH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFPHU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DFPHW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DPHC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DPHCU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DPHCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRNA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRAD: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DRADP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DLPNW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DSPG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DNKN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ETFC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - IGLE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ESSCR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ECHO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EDNT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EIDX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EIGI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EVSI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EVSIW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXFO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXPC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXPCU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EXPCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - STAY: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EYEG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EYEGW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLRZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FBSS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FDUSG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FDUSL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FDUSZ: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSRV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSRVU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSRVW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FTAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FTACU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FTACW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FEYE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FCBP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - INBKL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FPRX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FVE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLXN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLIR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FLWR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FSCT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FMCI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FMCIU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FMCIW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FRAN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - FORK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# -
: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - SVMK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - SYKE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - SYNC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TLC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TLND: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TLF: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TCF: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TCFCP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TNAV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TLGT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TZAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TZACU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TZACW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TCBIL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TCBIP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - XONE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MEET: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MIK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - PECK: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - PRSC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TXAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - THBR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - THBRU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - THBRW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TRCH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TOTA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TOTAR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TOTAU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TOTAW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - CLUB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TWMC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TBIO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TRMT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TPCO: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TDAC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TDACU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TDACW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - TRIL: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - THCB: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - THCBU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - THCBW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - USCR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LATN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LATNU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - LATNW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - UMRX: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - MYT: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - UROV: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VTEC: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VIE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VKTXW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VRTU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WSG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WTRE: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WTREP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WNFM: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WLTW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WINS: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WRTC: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WMGI: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - YIN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - YRCW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZGYH: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZGYHR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZGYHU: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZGYHW: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZAGG: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZNWAA: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZIONN: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZIOP: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ZIXI: No data found, symbol may be delisted
# Passing...
# (10291122, 12) (10291122,)
# (1143459, 12) (1143459,)
#           12_candels_close  11_candels_close  10_candels_close  \
# 0                 0.949209          2.169026          2.826810
# 1                 2.728791          3.256513          5.000000
# 2                 3.361582          5.000000          4.723791
# 3                 5.000000          4.723791          4.529190
# 4                 5.000000          4.794020          4.737542
# ...                    ...               ...               ...
# 11435404          0.833325          0.000000          0.000000
# 11435405          1.086958          1.086958          3.043479
# 11435406          1.399994          3.199997          4.799995
# 11435407          3.499998          4.833330          4.666659
# 11435408          4.857140          4.714279          4.285712
#
#           9_candels_close  8_candels_close  7_candels_close  6_candels_close  \
# 0                5.000000         4.633638         4.375520         4.304747
# 1                4.706078         4.498998         4.442218         2.428190
# 2                4.529190         4.475832         2.583176         2.099811
# 3                4.475832         2.583176         2.099811         1.230384
# 4                2.734219         2.222591         1.302326         1.647840
# ...                   ...              ...              ...              ...
# 11435404         2.500000         4.722216         4.444433         3.611108
# 11435405         4.782604         4.565208         3.913042         4.347813
# 11435406         4.599991         3.999996         4.399986         3.799992
# 11435407         4.166664         4.499989         3.999994         5.000000
# 11435408         4.571419         4.142852         5.000000         3.857132
#
#           5_candels_close  4_candels_close  3_candels_close  2_candels_close  \
# 0                1.794337         1.153204         0.000000         0.432971
# 1                1.913827         0.988645         1.336005         1.125585
# 2                1.230384         1.556811         1.359071         0.301318
# 3                1.556811         1.359071         0.301318         0.000000
# 4                1.438539         0.318937         0.000000         0.681063
# ...                   ...              ...              ...              ...
# 11435404         4.166649         3.333325         5.000000         2.777757
# 11435405         3.695646         5.000000         3.260854         2.391292
# 11435406         5.000000         3.399982         2.599983         0.399990
# 11435407         3.666653         2.999987         1.166661         0.833336
# 11435408         3.285704         1.714282         1.428575         0.714288
#
#           1_candels_close  suggestion
# 0                0.170691         0.0
# 1                0.000000         0.0
# 2                0.000000         1.0
# 3                0.643440         1.0
# 4                1.787376         0.0
# ...                   ...         ...
# 11435404         1.666649         0.0
# 11435405         0.000000         1.0
# 11435406         0.000000         0.0
# 11435407         0.000000         0.0
# 11435408         0.000000         1.0
#
# [11434581 rows x 13 columns]

# %%
model = Sequential()
adam = tf.keras.optimizers.Adam(
    learning_rate=0.001,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=True,
    name="Adam")


model.add(Dense(5000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(4096, activation='relu'))
model.add(Dense(2048, activation='relu'))
model.add(Dense(750, activation='relu'))
model.add(Dense(350, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=adam, loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_20 (Dense)            (None, 5000)              65000
#
#  dense_21 (Dense)            (None, 4096)              20484096
#
#  dense_22 (Dense)            (None, 2048)              8390656
#
#  dense_23 (Dense)            (None, 750)               1536750
#
#  dense_24 (Dense)            (None, 350)               262850
#
#  dense_25 (Dense)            (None, 1)                 351
#
#  dense_26 (Dense)            (None, 1)                 2
#
# =================================================================
# Total params: 30,739,705
# Trainable params: 30,739,705
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=111,batch_size=20000,validation_data=(xTest,yTest))
model.save(f"{model.evaluate(xTest,yTest)}.h5")
# Out:
# Epoch 1/111
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-b49d1ce50ef5> in <module>()
# ----> 1 model.fit(xTrain,yTrain,epochs=111,batch_size=20000,validation_data=(xTest,yTest))
#       2 model.save(f"{model.evaluate(xTest,yTest)}.h5")
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1382                 _r=1):
#    1383               callbacks.on_train_batch_begin(step)
# -> 1384               tmp_logs = self.train_function(iterator)
#    1385               if data_handler.should_sync:
#    1386                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     913
#     914       with OptionalXlaContext(self._jit_compile):
# --> 915         result = self._call(*args, **kwds)
#     916
#     917       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     978         # Lifting succeeded, so variables are initialized and we can run the
#     979         # stateless function.
# --> 980         return self._stateless_fn(*args, **kwds)
#     981     else:
#     982       _, _, _, filtered_flat_args = \
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2955        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2956     return graph_function._call_flat(
# -> 2957         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2958
#    2959   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1852       # No tape is watching; skip to running the function.
#    1853       return self._build_call_outputs(self._inference_function.call(
# -> 1854           ctx, args, cancellation_manager=cancellation_manager))
#    1855     forward_backward = self._select_forward_and_backward_functions(
#    1856         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     502               inputs=args,
#     503               attrs=attrs,
# --> 504               ctx=ctx)
#     505         else:
#     506           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      53     ctx.ensure_initialized()
#      54     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 55                                         inputs, attrs, num_outputs)
#      56   except core._NotOkStatusException as e:
#      57     if name is not None:
#
# KeyboardInterrupt:

# %%
clf = RandomForestClassifier(n_estimators=100)
clf.fit(xTrain,yTrain)
print(f"Random Forest :  {clf.score(xTest,yTest)}")
logisticRegr = LogisticRegression()
logisticRegr.fit(xTrain, yTrain)
print(f"Logistic Regression: {logisticRegr.score(xTest, yTest)}")
nc = NearestCentroid()
nc.fit(xTrain,yTrain)
print(f"Nearest Centroid: {nc.score(xTest,yTest)}")
gnb = GaussianNB()
gnb.fit(xTrain, yTrain)
print(f"GaussianNB: {gnb.score(xTest,yTest)}")
clf2 = KNeighborsClassifier(n_neighbors=2)
clf2.fit(xTrain, yTrain)
print(f"K-Neighbors: {clf2.score(xTest,yTest)}")
tree = DecisionTreeClassifier()
tree.fit(xTrain, yTrain)
print(f"Decision Tree: {tree.score(xTest,yTest)}")
gb = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
   max_depth=1, random_state=0).fit(xTrain, yTrain)
gb.fit(xTrain,yTrain)
print(f"Gradient Boost: {gb.score(xTest, yTest)}")
svm = SVC()
svm.fit(xTrain,yTrain)
print(f"SVM: {svm.score(xTest,yTest)}")

# %%
import os
files = os.listdir("/content/gdrive/MyDrive/Colab Files/")

data = pd.DataFrame()
for file in files:
  address = f"/content/gdrive/MyDrive/Colab Files/{file}"
  df = pd.read_csv(address)
  data = pd.concat([data,df])

# %%
symbols = read_syms_from_txt()
len(symbols)
pieces = 15
new_arrays = np.array_split(symbols, pieces)
for i in new_arrays:
  dfs = []
  for x in i:
        data = yf.download(x,period="MAX",interval="1d",progress=False)
        if data.empty :
             print("Passing...")
        else:
               dfs.append(data)
  ndfs = dfs
  dfs = []
  for df in ndfs:
        if df.shape[0] > 12:
          dfs.append(df)
  data = process(dfs)
  data.to_csv(f"{x}.csv")

# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
address = "/content/gdrive/MyDrive/Colab Files/063821.csv"
data = pd.read_csv(address)

data

# %%
data = data.drop(["Unnamed: 0"],axis=1)
xTrain, xTest, yTrain, yTest = spliting(data)
data

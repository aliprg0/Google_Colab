# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime
from numpy import array
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 24.5 MB/s
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 590 kB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70
# Collecting yahooquery
#   Downloading yahooquery-2.2.15-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.3 MB/s
# Collecting requests-futures>=1.0.0
#   Downloading requests_futures-1.0.0-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.3.5)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.64.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yahooquery) (1.15.0)
# Requirement already satisfied: requests>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from requests-futures>=1.0.0->yahooquery) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2021.10.8)
# Installing collected packages: requests-futures, yahooquery
# Successfully installed requests-futures-1.0.0 yahooquery-2.2.15

# %%
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
  #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
 'all_cryptocurrencies_us']
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(11,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-12][0],
                df[each-12][3],
                df[each-12][4],
                df[each-11][0],
                df[each-11][3],
                df[each-11][4],
                df[each-10][0],
                df[each-10][3],
                df[each-10][4],
                df[each-9][0],
                df[each-9][3],
                df[each-9][4],
                df[each-8][0],
                df[each-8][3],
                df[each-8][4],
                df[each-7][0],
                df[each-7][3],
                df[each-7][4],
                df[each-6][0],
                df[each-6][3],
                df[each-6][4],
                df[each-5][0],
                df[each-5][3],
                df[each-5][4],
                df[each-4][0],
                df[each-4][3],
                df[each-4][4],
                df[each-3][0],
                df[each-3][3],
                df[each-3][4],
                df[each-2][0],
                df[each-2][3],
                df[each-2][4],
                df[each-1][0],
                df[each-1][3],
                df[each-1][4],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(1,10))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object)
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled)
  df_scaled["suggestion"] = last_column
  return df_scaled
def stick_dfs(dfs):
  dataframe = dfs[0]
  for i in range(1,len(dfs)):
     dataframe = pd.concat([dataframe,dfs[i]], ignore_index = True)
  dataframe = dataframe.dropna()
  dataframe = dataframe.astype(float)
  return dataframe
def process(dfs): 
   fixed_dfs = []
   for df in dfs:
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df)
      df = row_scaler(df)
      #df = column_scaler(df)
      fixed_dfs.append(df)
   df = stick_dfs(fixed_dfs)
   return df

# %%
#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]

symbols = get_crypto_syms()
#symbols = read_syms_from_txt()
dfs = []
for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
             print("Passing...")
           else:
               dfs.append(data)
ndfs = dfs
dfs = []
for df in ndfs:
        if df.shape[0] > 13:
          dfs.append(df)

data = process(dfs)
xTrain, xTest, yTrain, yTest = spliting(data)
data
# Out:
# 1 Failed download:
# - EVER-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - 1ECO-USD: No data found for this date range, symbol may be delisted
# Passing...

# %%
model = Sequential()
adam = tf.keras.optimizers.Adam(
    learning_rate=0.01,
    beta_1=0.9,
    beta_2=0.999,
    epsilon=1e-07,
    amsgrad=True,
    name="Adam")

model.add(Dense(2000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(200, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer=adam, loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_14 (Dense)            (None, 2000)              50000
#
#  dense_15 (Dense)            (None, 200)               400200
#
#  dense_16 (Dense)            (None, 50)                10050
#
#  dense_17 (Dense)            (None, 1)                 51
#
# =================================================================
# Total params: 460,301
# Trainable params: 460,301
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=200,batch_size=1024,validation_data=(xTest,yTest))
# Out:
# Epoch 1/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6883 - accuracy: 0.5372 - val_loss: 0.6881 - val_accuracy: 0.5343
# Epoch 2/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6873 - accuracy: 0.5400 - val_loss: 0.6869 - val_accuracy: 0.5374
# Epoch 3/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6868 - accuracy: 0.5409 - val_loss: 0.6868 - val_accuracy: 0.5374
# Epoch 4/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6864 - accuracy: 0.5408 - val_loss: 0.6863 - val_accuracy: 0.5400
# Epoch 5/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6857 - accuracy: 0.5424 - val_loss: 0.6876 - val_accuracy: 0.5370
# Epoch 6/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6852 - accuracy: 0.5437 - val_loss: 0.6854 - val_accuracy: 0.5429
# Epoch 7/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6849 - accuracy: 0.5456 - val_loss: 0.6856 - val_accuracy: 0.5428
# Epoch 8/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6844 - accuracy: 0.5448 - val_loss: 0.6849 - val_accuracy: 0.5432
# Epoch 9/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6837 - accuracy: 0.5466 - val_loss: 0.6851 - val_accuracy: 0.5429
# Epoch 10/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6840 - accuracy: 0.5461 - val_loss: 0.6850 - val_accuracy: 0.5418
# Epoch 11/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6830 - accuracy: 0.5474 - val_loss: 0.6845 - val_accuracy: 0.5451
# Epoch 12/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6826 - accuracy: 0.5502 - val_loss: 0.6836 - val_accuracy: 0.5478
# Epoch 13/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6824 - accuracy: 0.5498 - val_loss: 0.6834 - val_accuracy: 0.5480
# Epoch 14/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6820 - accuracy: 0.5495 - val_loss: 0.6841 - val_accuracy: 0.5462
# Epoch 15/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6816 - accuracy: 0.5518 - val_loss: 0.6825 - val_accuracy: 0.5476
# Epoch 16/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6818 - accuracy: 0.5501 - val_loss: 0.6846 - val_accuracy: 0.5438
# Epoch 17/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6813 - accuracy: 0.5524 - val_loss: 0.6821 - val_accuracy: 0.5524
# Epoch 18/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6807 - accuracy: 0.5527 - val_loss: 0.6823 - val_accuracy: 0.5517
# Epoch 19/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6810 - accuracy: 0.5543 - val_loss: 0.6823 - val_accuracy: 0.5484
# Epoch 20/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6807 - accuracy: 0.5539 - val_loss: 0.6826 - val_accuracy: 0.5500
# Epoch 21/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6804 - accuracy: 0.5549 - val_loss: 0.6829 - val_accuracy: 0.5532
# Epoch 22/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6805 - accuracy: 0.5538 - val_loss: 0.6821 - val_accuracy: 0.5527
# Epoch 23/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6799 - accuracy: 0.5551 - val_loss: 0.6821 - val_accuracy: 0.5500
# Epoch 24/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6798 - accuracy: 0.5551 - val_loss: 0.6831 - val_accuracy: 0.5492
# Epoch 25/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6794 - accuracy: 0.5562 - val_loss: 0.6837 - val_accuracy: 0.5473
# Epoch 26/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6791 - accuracy: 0.5588 - val_loss: 0.6819 - val_accuracy: 0.5510
# Epoch 27/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6792 - accuracy: 0.5576 - val_loss: 0.6818 - val_accuracy: 0.5548
# Epoch 28/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6786 - accuracy: 0.5589 - val_loss: 0.6802 - val_accuracy: 0.5585
# Epoch 29/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6786 - accuracy: 0.5588 - val_loss: 0.6813 - val_accuracy: 0.5559
# Epoch 30/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6786 - accuracy: 0.5582 - val_loss: 0.6812 - val_accuracy: 0.5560
# Epoch 31/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6780 - accuracy: 0.5605 - val_loss: 0.6818 - val_accuracy: 0.5567
# Epoch 32/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6780 - accuracy: 0.5611 - val_loss: 0.6805 - val_accuracy: 0.5571
# Epoch 33/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6779 - accuracy: 0.5602 - val_loss: 0.6806 - val_accuracy: 0.5544
# Epoch 34/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6776 - accuracy: 0.5623 - val_loss: 0.6812 - val_accuracy: 0.5576
# Epoch 35/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6776 - accuracy: 0.5606 - val_loss: 0.6815 - val_accuracy: 0.5526
# Epoch 36/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6771 - accuracy: 0.5620 - val_loss: 0.6804 - val_accuracy: 0.5588
# Epoch 37/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6769 - accuracy: 0.5623 - val_loss: 0.6822 - val_accuracy: 0.5587
# Epoch 38/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6766 - accuracy: 0.5642 - val_loss: 0.6800 - val_accuracy: 0.5572
# Epoch 39/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6763 - accuracy: 0.5657 - val_loss: 0.6804 - val_accuracy: 0.5597
# Epoch 40/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6764 - accuracy: 0.5631 - val_loss: 0.6802 - val_accuracy: 0.5593
# Epoch 41/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6764 - accuracy: 0.5638 - val_loss: 0.6811 - val_accuracy: 0.5541
# Epoch 42/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6756 - accuracy: 0.5663 - val_loss: 0.6793 - val_accuracy: 0.5630
# Epoch 43/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6756 - accuracy: 0.5651 - val_loss: 0.6808 - val_accuracy: 0.5566
# Epoch 44/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6756 - accuracy: 0.5651 - val_loss: 0.6797 - val_accuracy: 0.5612
# Epoch 45/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6755 - accuracy: 0.5666 - val_loss: 0.6784 - val_accuracy: 0.5611
# Epoch 46/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6753 - accuracy: 0.5666 - val_loss: 0.6804 - val_accuracy: 0.5589
# Epoch 47/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6748 - accuracy: 0.5693 - val_loss: 0.6794 - val_accuracy: 0.5588
# Epoch 48/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6752 - accuracy: 0.5656 - val_loss: 0.6792 - val_accuracy: 0.5603
# Epoch 49/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6752 - accuracy: 0.5665 - val_loss: 0.6805 - val_accuracy: 0.5552
# Epoch 50/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6743 - accuracy: 0.5683 - val_loss: 0.6784 - val_accuracy: 0.5614
# Epoch 51/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6745 - accuracy: 0.5678 - val_loss: 0.6783 - val_accuracy: 0.5616
# Epoch 52/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6744 - accuracy: 0.5673 - val_loss: 0.6779 - val_accuracy: 0.5630
# Epoch 53/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6738 - accuracy: 0.5698 - val_loss: 0.6787 - val_accuracy: 0.5590
# Epoch 54/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6737 - accuracy: 0.5698 - val_loss: 0.6785 - val_accuracy: 0.5645
# Epoch 55/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6737 - accuracy: 0.5700 - val_loss: 0.6784 - val_accuracy: 0.5608
# Epoch 56/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6733 - accuracy: 0.5694 - val_loss: 0.6785 - val_accuracy: 0.5618
# Epoch 57/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6734 - accuracy: 0.5699 - val_loss: 0.6786 - val_accuracy: 0.5592
# Epoch 58/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6731 - accuracy: 0.5713 - val_loss: 0.6787 - val_accuracy: 0.5619
# Epoch 59/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6728 - accuracy: 0.5707 - val_loss: 0.6808 - val_accuracy: 0.5539
# Epoch 60/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6727 - accuracy: 0.5712 - val_loss: 0.6781 - val_accuracy: 0.5630
# Epoch 61/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6726 - accuracy: 0.5713 - val_loss: 0.6782 - val_accuracy: 0.5589
# Epoch 62/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6721 - accuracy: 0.5719 - val_loss: 0.6784 - val_accuracy: 0.5600
# Epoch 63/200
# 200/200 [==============================] - 1s 4ms/step - loss: 0.6720 - accuracy: 0.5726 - val_loss: 0.6784 - val_accuracy: 0.5615
# Epoch 64/200
#  72/200 [=========>....................] - ETA: 0s - loss: 0.6720 - accuracy: 0.5723
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-60d5ff1e2cf4> in <module>()
# ----> 1 model.fit(xTrain,yTrain,epochs=200,batch_size=1024,validation_data=(xTest,yTest))
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1387               logs = tmp_logs  # No error, now safe to assign to logs.
#    1388               end_step = step + data_handler.step_increment
# -> 1389               callbacks.on_train_batch_end(end_step, logs)
#    1390               if self.stop_training:
#    1391                 break
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#     436     """
#     437     if self._should_call_train_batch_hooks:
# --> 438       self._call_batch_hook(ModeKeys.TRAIN, 'end', batch, logs=logs)
#     439
#     440   def on_test_batch_begin(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook(self, mode, hook, batch, logs)
#     295       self._call_batch_begin_hook(mode, batch, logs)
#     296     elif hook == 'end':
# --> 297       self._call_batch_end_hook(mode, batch, logs)
#     298     else:
#     299       raise ValueError(
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_end_hook(self, mode, batch, logs)
#     316       self._batch_times.append(batch_time)
#     317
# --> 318     self._call_batch_hook_helper(hook_name, batch, logs)
#     319
#     320     if len(self._batch_times) >= self._num_batches_for_timing_check:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _call_batch_hook_helper(self, hook_name, batch, logs)
#     354     for callback in self.callbacks:
#     355       hook = getattr(callback, hook_name)
# --> 356       hook(batch, logs)
#     357
#     358     if self._check_timing:
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in on_train_batch_end(self, batch, logs)
#    1032
#    1033   def on_train_batch_end(self, batch, logs=None):
# -> 1034     self._batch_update_progbar(batch, logs)
#    1035
#    1036   def on_test_batch_end(self, batch, logs=None):
#
# /usr/local/lib/python3.7/dist-packages/keras/callbacks.py in _batch_update_progbar(self, batch, logs)
#    1104     if self.verbose == 1:
#    1105       # Only block async when verbose = 1.
# -> 1106       logs = tf_utils.sync_to_numpy_or_python_type(logs)
#    1107       self.progbar.update(self.seen, list(logs.items()), finalize=False)
#    1108
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in sync_to_numpy_or_python_type(tensors)
#     561     return t.item() if np.ndim(t) == 0 else t
#     562
# --> 563   return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#     564
#     565
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in <listcomp>(.0)
#     912
#     913   return pack_sequence_as(
# --> 914       structure[0], [func(*x) for x in entries],
#     915       expand_composites=expand_composites)
#     916
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/tf_utils.py in _to_single_numpy_or_python_type(t)
#     555     # Don't turn ragged or sparse tensors to NumPy.
#     556     if isinstance(t, tf.Tensor):
# --> 557       t = t.numpy()
#     558     # Strings, ragged and sparse tensors don't have .item(). Return them as-is.
#     559     if not isinstance(t, (np.ndarray, np.generic)):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in numpy(self)
#    1221     """
#    1222     # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1223     maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1224     return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#    1225
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/ops.py in _numpy(self)
#    1187   def _numpy(self):
#    1188     try:
# -> 1189       return self._numpy_internal()
#    1190     except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1191       raise core._status_to_exception(e) from None  # pylint: disable=protected-access
#
# KeyboardInterrupt:

# %%
from google.colab import drive
drive.mount("/content/gdrive/")
# Out:
# Mounted at /content/gdrive/

# %%
address = "/content/gdrive/MyDrive/Colab Files/12c_05sclaer.csv"
data = pd.read_csv(address)

data
# Out:
#           Unnamed: 0  12_candels_close  11_candels_close  10_candels_close  \
# 0                  0          0.949209          2.169026          2.826810
# 1                  1          2.728791          3.256513          5.000000
# 2                  2          3.361582          5.000000          4.723791
# 3                  3          5.000000          4.723791          4.529190
# 4                  4          5.000000          4.794020          4.737542
# ...              ...               ...               ...               ...
# 11434576    11435404          0.833325          0.000000          0.000000
# 11434577    11435405          1.086958          1.086958          3.043479
# 11434578    11435406          1.399994          3.199997          4.799995
# 11434579    11435407          3.499998          4.833330          4.666659
# 11434580    11435408          4.857140          4.714279          4.285712
#
#           9_candels_close  8_candels_close  7_candels_close  6_candels_close  \
# 0                5.000000         4.633638         4.375520         4.304747
# 1                4.706078         4.498998         4.442218         2.428190
# 2                4.529190         4.475832         2.583176         2.099811
# 3                4.475832         2.583176         2.099811         1.230384
# 4                2.734219         2.222591         1.302326         1.647840
# ...                   ...              ...              ...              ...
# 11434576         2.500000         4.722216         4.444433         3.611108
# 11434577         4.782604         4.565208         3.913042         4.347813
# 11434578         4.599991         3.999996         4.399986         3.799992
# 11434579         4.166664         4.499989         3.999994         5.000000
# 11434580         4.571419         4.142852         5.000000         3.857132
#
#           5_candels_close  4_candels_close  3_candels_close  2_candels_close  \
# 0                1.794337         1.153204         0.000000         0.432971
# 1                1.913827         0.988645         1.336005         1.125585
# 2                1.230384         1.556811         1.359071         0.301318
# 3                1.556811         1.359071         0.301318         0.000000
# 4                1.438539         0.318937         0.000000         0.681063
# ...                   ...              ...              ...              ...
# 11434576         4.166649         3.333325         5.000000         2.777757
# 11434577         3.695646         5.000000         3.260854         2.391292
# 11434578         5.000000         3.399982         2.599983         0.399990
# 11434579         3.666653         2.999987         1.166661         0.833336
# 11434580         3.285704         1.714282         1.428575         0.714288
#
#           1_candels_close  suggestion
# 0                0.170691         0.0
# 1                0.000000         0.0
# 2                0.000000         1.0
# 3                0.643440         1.0
# 4                1.787376         0.0
# ...                   ...         ...
# 11434576         1.666649         0.0
# 11434577         0.000000         1.0
# 11434578         0.000000         0.0
# 11434579         0.000000         0.0
# 11434580         0.000000         1.0
#
# [11434581 rows x 14 columns]

# %%
data = data.drop(["Unnamed: 0"],axis=1)
xTrain, xTest, yTrain, yTest = spliting(data)
data
# Out:
# (10291122, 12) (10291122,)
# (1143459, 12) (1143459,)
#           12_candels_close  11_candels_close  10_candels_close  \
# 0                 0.949209          2.169026          2.826810
# 1                 2.728791          3.256513          5.000000
# 2                 3.361582          5.000000          4.723791
# 3                 5.000000          4.723791          4.529190
# 4                 5.000000          4.794020          4.737542
# ...                    ...               ...               ...
# 11434576          0.833325          0.000000          0.000000
# 11434577          1.086958          1.086958          3.043479
# 11434578          1.399994          3.199997          4.799995
# 11434579          3.499998          4.833330          4.666659
# 11434580          4.857140          4.714279          4.285712
#
#           9_candels_close  8_candels_close  7_candels_close  6_candels_close  \
# 0                5.000000         4.633638         4.375520         4.304747
# 1                4.706078         4.498998         4.442218         2.428190
# 2                4.529190         4.475832         2.583176         2.099811
# 3                4.475832         2.583176         2.099811         1.230384
# 4                2.734219         2.222591         1.302326         1.647840
# ...                   ...              ...              ...              ...
# 11434576         2.500000         4.722216         4.444433         3.611108
# 11434577         4.782604         4.565208         3.913042         4.347813
# 11434578         4.599991         3.999996         4.399986         3.799992
# 11434579         4.166664         4.499989         3.999994         5.000000
# 11434580         4.571419         4.142852         5.000000         3.857132
#
#           5_candels_close  4_candels_close  3_candels_close  2_candels_close  \
# 0                1.794337         1.153204         0.000000         0.432971
# 1                1.913827         0.988645         1.336005         1.125585
# 2                1.230384         1.556811         1.359071         0.301318
# 3                1.556811         1.359071         0.301318         0.000000
# 4                1.438539         0.318937         0.000000         0.681063
# ...                   ...              ...              ...              ...
# 11434576         4.166649         3.333325         5.000000         2.777757
# 11434577         3.695646         5.000000         3.260854         2.391292
# 11434578         5.000000         3.399982         2.599983         0.399990
# 11434579         3.666653         2.999987         1.166661         0.833336
# 11434580         3.285704         1.714282         1.428575         0.714288
#
#           1_candels_close  suggestion
# 0                0.170691         0.0
# 1                0.000000         0.0
# 2                0.000000         1.0
# 3                0.643440         1.0
# 4                1.787376         0.0
# ...                   ...         ...
# 11434576         1.666649         0.0
# 11434577         0.000000         1.0
# 11434578         0.000000         0.0
# 11434579         0.000000         0.0
# 11434580         0.000000         1.0
#
# [11434581 rows x 13 columns]

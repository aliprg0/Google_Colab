# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime
from numpy import array
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 24.5 MB/s
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 590 kB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70
# Collecting yahooquery
#   Downloading yahooquery-2.2.15-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.3 MB/s
# Collecting requests-futures>=1.0.0
#   Downloading requests_futures-1.0.0-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.3.5)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.64.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yahooquery) (1.15.0)
# Requirement already satisfied: requests>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from requests-futures>=1.0.0->yahooquery) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2021.10.8)
# Installing collected packages: requests-futures, yahooquery
# Successfully installed requests-futures-1.0.0 yahooquery-2.2.15

# %%
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
  #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
    'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in','all_cryptocurrencies_us']
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(11,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-12][0],
                df[each-12][3],
                df[each-12][4],
                df[each-11][0],
                df[each-11][3],
                df[each-11][4],
                df[each-10][0],
                df[each-10][3],
                df[each-10][4],
                df[each-9][0],
                df[each-9][3],
                df[each-9][4],
                df[each-8][0],
                df[each-8][3],
                df[each-8][4],
                df[each-7][0],
                df[each-7][3],
                df[each-7][4],
                df[each-6][0],
                df[each-6][3],
                df[each-6][4],
                df[each-5][0],
                df[each-5][3],
                df[each-5][4],
                df[each-4][0],
                df[each-4][3],
                df[each-4][4],
                df[each-3][0],
                df[each-3][3],
                df[each-3][4],
                df[each-2][0],
                df[each-2][3],
                df[each-2][4],
                df[each-1][0],
                df[each-1][3],
                df[each-1][4],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object)
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled)
  df_scaled["suggestion"] = last_column
  return df_scaled
def stick_dfs(dfs):
  dataframe = dfs[0]
  for i in range(1,len(dfs)):
     dataframe = pd.concat([dataframe,dfs[i]], ignore_index = True)
  dataframe = dataframe.dropna()
  dataframe = dataframe.astype(float)
  return dataframe
def process(dfs): 
   fixed_dfs = []
   for df in dfs:
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df)
      df = row_scaler(df)
      #df = column_scaler(df)
      fixed_dfs.append(df)
   df = stick_dfs(fixed_dfs)
   return df

# %%
#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]

symbols = get_crypto_syms()
#symbols = read_syms_from_txt()
dfs = []
for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
             print("Passing...")
           else:
               dfs.append(data)
ndfs = dfs
dfs = []
for df in ndfs:
        if df.shape[0] > 13:
          dfs.append(df)

data = process(dfs)
xTrain, xTest, yTrain, yTest = spliting(data)
data

# %%
from google.colab import drive
drive.mount("/content/drive")

data = df.read_csv("/content/drive/MyDrive/Colab Files/df_BinaryTesting02.csv")
# Out:
#                  0         1         2         3         4         5  \
# 0        10.000000  9.962342  9.962342  1.011749  1.011339  1.011339
# 1        10.000000  9.725496  9.725496  9.666847  5.515231  5.515231
# 2        10.000000  5.736592  5.736592  5.693888  2.277124  2.277124
# 3         7.035992  2.642286  2.642286  2.622124  4.954872  4.954872
# 4         2.622124  4.954872  4.954872  4.820620  3.236222  3.236222
# ...            ...       ...       ...       ...       ...       ...
# 1765264   1.642061  3.063500  3.063500  3.061348  1.052867  1.052867
# 1765265   3.937438  2.182552  2.182552  2.183959  2.136360  2.136360
# 1765266   2.183959  2.136360  2.136360  2.138111  2.463915  2.463915
# 1765267   2.138111  2.463915  2.463915  2.463166  6.006860  6.006860
# 1765268   2.463166  6.006860  6.006860  6.011186  2.630554  2.630554
#
#                 6         7         8         9  ...        27         28  \
# 0        1.011252  1.005053  1.005053  1.004991  ...  1.005890   1.004207
# 1        5.473647  2.146474  2.146474  2.131205  ...  4.930512   4.281240
# 2        2.261444  4.075505  4.075505  3.971105  ...  4.356526   3.832417
# 3        4.820620  3.236222  3.236222  3.281911  ...  4.634102   1.128308
# 4        3.281911  4.226854  4.226854  4.216962  ...  1.085915   1.000000
# ...           ...       ...       ...       ...  ...       ...        ...
# 1765264  1.054477  1.000000  1.000000  1.002004  ...  3.074995   8.558728
# 1765265  2.138111  2.463915  2.463915  2.463166  ...  8.740223  10.000000
# 1765266  2.463166  6.006860  6.006860  6.011186  ...  9.999899   6.141116
# 1765267  6.011186  2.630554  2.630554  2.630223  ...  6.140918   1.000000
# 1765268  2.630223  3.048352  3.048352  3.047308  ...  1.000924   3.114194
#
#                 29        30         31         32        33        34  \
# 0         1.004207  1.004180   1.003210   1.003210  1.003046  1.002284
# 1         4.281240  4.171352   3.660986   3.660986  3.654794  1.000000
# 2         3.832417  3.826059   1.099779   1.099779  1.066812  1.000000
# 3         1.128308  1.085915   1.000000   1.000000  1.104318  2.741943
# 4         1.000000  1.104318   2.741943   2.741943  2.822847  2.140218
# ...            ...       ...        ...        ...       ...       ...
# 1765264   8.558728  8.558176  10.000000  10.000000  9.999884  5.583475
# 1765265  10.000000  9.999899   6.141116   6.141116  6.140918  1.000000
# 1765266   6.141116  6.140918   1.000000   1.000000  1.000924  3.114194
# 1765267   1.000000  1.000924   3.114194   3.114194  3.114139  5.564232
# 1765268   3.114194  3.114139   5.564232   5.564232  5.563657  1.767651
#
#                35  suggestion
# 0        1.002284         0.0
# 1        1.000000         0.0
# 2        1.000000         1.0
# 3        2.741943         0.0
# 4        2.140218         0.0
# ...           ...         ...
# 1765264  5.583475         0.0
# 1765265  1.000000         1.0
# 1765266  3.114194         1.0
# 1765267  5.564232         0.0
# 1765268  1.767651         0.0
#
# [1765269 rows x 37 columns]

# %%
model = Sequential()


model.add(Dense(2000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(1000, activation='relu'))
model.add(Dense(500, activation='relu'))
model.add(Dense(250, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_47 (Dense)            (None, 2000)              74000
#
#  dense_48 (Dense)            (None, 1000)              2001000
#
#  dense_49 (Dense)            (None, 500)               500500
#
#  dense_50 (Dense)            (None, 250)               125250
#
#  dense_51 (Dense)            (None, 100)               25100
#
#  dense_52 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 2,725,951
# Trainable params: 2,725,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=123,batch_size=2024,validation_data=(xTest,yTest))
# Out:
# Epoch 1/123
# 785/785 [==============================] - 10s 12ms/step - loss: 0.6897 - accuracy: 0.5412 - val_loss: 0.6894 - val_accuracy: 0.5432
# Epoch 2/123
# 785/785 [==============================] - 9s 11ms/step - loss: 0.6785 - accuracy: 0.5634 - val_loss: 0.6725 - val_accuracy: 0.5722
# Epoch 3/123
# 785/785 [==============================] - 9s 11ms/step - loss: 0.6621 - accuracy: 0.5876 - val_loss: 0.6518 - val_accuracy: 0.6012
# Epoch 4/123
# 785/785 [==============================] - 9s 11ms/step - loss: 0.6392 - accuracy: 0.6161 - val_loss: 0.6286 - val_accuracy: 0.6281
# Epoch 5/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.6130 - accuracy: 0.6453 - val_loss: 0.6063 - val_accuracy: 0.6532
# Epoch 6/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.5808 - accuracy: 0.6776 - val_loss: 0.5772 - val_accuracy: 0.6825
# Epoch 7/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.5391 - accuracy: 0.7152 - val_loss: 0.5424 - val_accuracy: 0.7137
# Epoch 8/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.4899 - accuracy: 0.7544 - val_loss: 0.5015 - val_accuracy: 0.7482
# Epoch 9/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.4394 - accuracy: 0.7897 - val_loss: 0.4672 - val_accuracy: 0.7762
# Epoch 10/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.3923 - accuracy: 0.8200 - val_loss: 0.4385 - val_accuracy: 0.7990
# Epoch 11/123
# 785/785 [==============================] - 9s 11ms/step - loss: 0.3524 - accuracy: 0.8436 - val_loss: 0.4164 - val_accuracy: 0.8167
# Epoch 12/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.3192 - accuracy: 0.8625 - val_loss: 0.3895 - val_accuracy: 0.8365
# Epoch 13/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.2911 - accuracy: 0.8780 - val_loss: 0.3725 - val_accuracy: 0.8482
# Epoch 14/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.2688 - accuracy: 0.8896 - val_loss: 0.3667 - val_accuracy: 0.8557
# Epoch 15/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.2495 - accuracy: 0.8990 - val_loss: 0.3511 - val_accuracy: 0.8663
# Epoch 16/123
# 785/785 [==============================] - 9s 11ms/step - loss: 0.2341 - accuracy: 0.9067 - val_loss: 0.3472 - val_accuracy: 0.8696
# Epoch 17/123
# 785/785 [==============================] - 9s 11ms/step - loss: 0.2202 - accuracy: 0.9128 - val_loss: 0.3378 - val_accuracy: 0.8773
# Epoch 18/123
# 785/785 [==============================] - 9s 11ms/step - loss: 0.2089 - accuracy: 0.9181 - val_loss: 0.3409 - val_accuracy: 0.8777
# Epoch 19/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1982 - accuracy: 0.9229 - val_loss: 0.3347 - val_accuracy: 0.8837
# Epoch 20/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1909 - accuracy: 0.9263 - val_loss: 0.3317 - val_accuracy: 0.8867
# Epoch 21/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1830 - accuracy: 0.9297 - val_loss: 0.3385 - val_accuracy: 0.8847
# Epoch 22/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1754 - accuracy: 0.9331 - val_loss: 0.3392 - val_accuracy: 0.8877
# Epoch 23/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1687 - accuracy: 0.9358 - val_loss: 0.3290 - val_accuracy: 0.8930
# Epoch 24/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1637 - accuracy: 0.9382 - val_loss: 0.3330 - val_accuracy: 0.8943
# Epoch 25/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1579 - accuracy: 0.9405 - val_loss: 0.3313 - val_accuracy: 0.8934
# Epoch 26/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1533 - accuracy: 0.9422 - val_loss: 0.3294 - val_accuracy: 0.8989
# Epoch 27/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1488 - accuracy: 0.9440 - val_loss: 0.3272 - val_accuracy: 0.9003
# Epoch 28/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1452 - accuracy: 0.9456 - val_loss: 0.3266 - val_accuracy: 0.9021
# Epoch 29/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1405 - accuracy: 0.9475 - val_loss: 0.3262 - val_accuracy: 0.9028
# Epoch 30/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1372 - accuracy: 0.9492 - val_loss: 0.3275 - val_accuracy: 0.9015
# Epoch 31/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1345 - accuracy: 0.9503 - val_loss: 0.3281 - val_accuracy: 0.9038
# Epoch 32/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1313 - accuracy: 0.9513 - val_loss: 0.3256 - val_accuracy: 0.9059
# Epoch 33/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1282 - accuracy: 0.9525 - val_loss: 0.3271 - val_accuracy: 0.9056
# Epoch 34/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1256 - accuracy: 0.9537 - val_loss: 0.3250 - val_accuracy: 0.9077
# Epoch 35/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1221 - accuracy: 0.9550 - val_loss: 0.3356 - val_accuracy: 0.9061
# Epoch 36/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1203 - accuracy: 0.9556 - val_loss: 0.3268 - val_accuracy: 0.9093
# Epoch 37/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1178 - accuracy: 0.9567 - val_loss: 0.3276 - val_accuracy: 0.9094
# Epoch 38/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1154 - accuracy: 0.9577 - val_loss: 0.3305 - val_accuracy: 0.9108
# Epoch 39/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1141 - accuracy: 0.9580 - val_loss: 0.3335 - val_accuracy: 0.9092
# Epoch 40/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1111 - accuracy: 0.9595 - val_loss: 0.3302 - val_accuracy: 0.9101
# Epoch 41/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1087 - accuracy: 0.9603 - val_loss: 0.3272 - val_accuracy: 0.9125
# Epoch 42/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1081 - accuracy: 0.9606 - val_loss: 0.3360 - val_accuracy: 0.9108
# Epoch 43/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1064 - accuracy: 0.9612 - val_loss: 0.3360 - val_accuracy: 0.9113
# Epoch 44/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1039 - accuracy: 0.9622 - val_loss: 0.3323 - val_accuracy: 0.9130
# Epoch 45/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1018 - accuracy: 0.9628 - val_loss: 0.3310 - val_accuracy: 0.9141
# Epoch 46/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.1015 - accuracy: 0.9630 - val_loss: 0.3324 - val_accuracy: 0.9130
# Epoch 47/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0990 - accuracy: 0.9640 - val_loss: 0.3344 - val_accuracy: 0.9131
# Epoch 48/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0978 - accuracy: 0.9645 - val_loss: 0.3397 - val_accuracy: 0.9128
# Epoch 49/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0964 - accuracy: 0.9651 - val_loss: 0.3326 - val_accuracy: 0.9155
# Epoch 50/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0953 - accuracy: 0.9657 - val_loss: 0.3290 - val_accuracy: 0.9153
# Epoch 51/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0933 - accuracy: 0.9663 - val_loss: 0.3324 - val_accuracy: 0.9159
# Epoch 52/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0929 - accuracy: 0.9664 - val_loss: 0.3324 - val_accuracy: 0.9174
# Epoch 53/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0903 - accuracy: 0.9676 - val_loss: 0.3360 - val_accuracy: 0.9169
# Epoch 54/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0908 - accuracy: 0.9673 - val_loss: 0.3329 - val_accuracy: 0.9179
# Epoch 55/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0877 - accuracy: 0.9685 - val_loss: 0.3386 - val_accuracy: 0.9183
# Epoch 56/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0874 - accuracy: 0.9685 - val_loss: 0.3369 - val_accuracy: 0.9168
# Epoch 57/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0871 - accuracy: 0.9686 - val_loss: 0.3380 - val_accuracy: 0.9173
# Epoch 58/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0853 - accuracy: 0.9693 - val_loss: 0.3451 - val_accuracy: 0.9174
# Epoch 59/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0841 - accuracy: 0.9698 - val_loss: 0.3393 - val_accuracy: 0.9194
# Epoch 60/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0830 - accuracy: 0.9701 - val_loss: 0.3397 - val_accuracy: 0.9198
# Epoch 61/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0816 - accuracy: 0.9709 - val_loss: 0.3417 - val_accuracy: 0.9207
# Epoch 62/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0815 - accuracy: 0.9708 - val_loss: 0.3488 - val_accuracy: 0.9173
# Epoch 63/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0811 - accuracy: 0.9710 - val_loss: 0.3402 - val_accuracy: 0.9198
# Epoch 64/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0793 - accuracy: 0.9716 - val_loss: 0.3450 - val_accuracy: 0.9204
# Epoch 65/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0787 - accuracy: 0.9717 - val_loss: 0.3465 - val_accuracy: 0.9190
# Epoch 66/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0781 - accuracy: 0.9720 - val_loss: 0.3468 - val_accuracy: 0.9186
# Epoch 67/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0764 - accuracy: 0.9728 - val_loss: 0.3489 - val_accuracy: 0.9195
# Epoch 68/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0770 - accuracy: 0.9723 - val_loss: 0.3475 - val_accuracy: 0.9209
# Epoch 69/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0753 - accuracy: 0.9731 - val_loss: 0.3450 - val_accuracy: 0.9206
# Epoch 70/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0744 - accuracy: 0.9734 - val_loss: 0.3476 - val_accuracy: 0.9206
# Epoch 71/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0740 - accuracy: 0.9736 - val_loss: 0.3471 - val_accuracy: 0.9206
# Epoch 72/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0727 - accuracy: 0.9742 - val_loss: 0.3539 - val_accuracy: 0.9192
# Epoch 73/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0724 - accuracy: 0.9741 - val_loss: 0.3498 - val_accuracy: 0.9206
# Epoch 74/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0719 - accuracy: 0.9744 - val_loss: 0.3608 - val_accuracy: 0.9200
# Epoch 75/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0706 - accuracy: 0.9748 - val_loss: 0.3494 - val_accuracy: 0.9217
# Epoch 76/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0703 - accuracy: 0.9750 - val_loss: 0.3536 - val_accuracy: 0.9213
# Epoch 77/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0696 - accuracy: 0.9754 - val_loss: 0.3544 - val_accuracy: 0.9226
# Epoch 78/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0689 - accuracy: 0.9755 - val_loss: 0.3537 - val_accuracy: 0.9234
# Epoch 79/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0684 - accuracy: 0.9756 - val_loss: 0.3557 - val_accuracy: 0.9230
# Epoch 80/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0680 - accuracy: 0.9759 - val_loss: 0.3573 - val_accuracy: 0.9203
# Epoch 81/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0673 - accuracy: 0.9760 - val_loss: 0.3485 - val_accuracy: 0.9233
# Epoch 82/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0662 - accuracy: 0.9764 - val_loss: 0.3550 - val_accuracy: 0.9227
# Epoch 83/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0661 - accuracy: 0.9766 - val_loss: 0.3542 - val_accuracy: 0.9224
# Epoch 84/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0653 - accuracy: 0.9768 - val_loss: 0.3540 - val_accuracy: 0.9229
# Epoch 85/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0657 - accuracy: 0.9766 - val_loss: 0.3550 - val_accuracy: 0.9223
# Epoch 86/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0638 - accuracy: 0.9775 - val_loss: 0.3555 - val_accuracy: 0.9235
# Epoch 87/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0636 - accuracy: 0.9775 - val_loss: 0.3626 - val_accuracy: 0.9207
# Epoch 88/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0633 - accuracy: 0.9776 - val_loss: 0.3587 - val_accuracy: 0.9244
# Epoch 89/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0628 - accuracy: 0.9777 - val_loss: 0.3615 - val_accuracy: 0.9239
# Epoch 90/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0619 - accuracy: 0.9781 - val_loss: 0.3659 - val_accuracy: 0.9226
# Epoch 91/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0621 - accuracy: 0.9779 - val_loss: 0.3649 - val_accuracy: 0.9231
# Epoch 92/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0610 - accuracy: 0.9784 - val_loss: 0.3625 - val_accuracy: 0.9243
# Epoch 93/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0612 - accuracy: 0.9783 - val_loss: 0.3662 - val_accuracy: 0.9236
# Epoch 94/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0610 - accuracy: 0.9784 - val_loss: 0.3575 - val_accuracy: 0.9234
# Epoch 95/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0597 - accuracy: 0.9788 - val_loss: 0.3678 - val_accuracy: 0.9243
# Epoch 96/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0594 - accuracy: 0.9790 - val_loss: 0.3631 - val_accuracy: 0.9237
# Epoch 97/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0588 - accuracy: 0.9791 - val_loss: 0.3644 - val_accuracy: 0.9237
# Epoch 98/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0584 - accuracy: 0.9793 - val_loss: 0.3683 - val_accuracy: 0.9250
# Epoch 99/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0583 - accuracy: 0.9792 - val_loss: 0.3616 - val_accuracy: 0.9261
# Epoch 100/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0577 - accuracy: 0.9796 - val_loss: 0.3699 - val_accuracy: 0.9251
# Epoch 101/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0576 - accuracy: 0.9796 - val_loss: 0.3641 - val_accuracy: 0.9251
# Epoch 102/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0573 - accuracy: 0.9796 - val_loss: 0.3653 - val_accuracy: 0.9257
# Epoch 103/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0566 - accuracy: 0.9799 - val_loss: 0.3733 - val_accuracy: 0.9238
# Epoch 104/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0562 - accuracy: 0.9801 - val_loss: 0.3726 - val_accuracy: 0.9247
# Epoch 105/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0560 - accuracy: 0.9802 - val_loss: 0.3710 - val_accuracy: 0.9253
# Epoch 106/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0557 - accuracy: 0.9803 - val_loss: 0.3676 - val_accuracy: 0.9258
# Epoch 107/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0549 - accuracy: 0.9806 - val_loss: 0.3737 - val_accuracy: 0.9259
# Epoch 108/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0551 - accuracy: 0.9806 - val_loss: 0.3706 - val_accuracy: 0.9268
# Epoch 109/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0543 - accuracy: 0.9809 - val_loss: 0.3697 - val_accuracy: 0.9255
# Epoch 110/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0547 - accuracy: 0.9806 - val_loss: 0.3773 - val_accuracy: 0.9253
# Epoch 111/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0538 - accuracy: 0.9809 - val_loss: 0.3789 - val_accuracy: 0.9255
# Epoch 112/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0531 - accuracy: 0.9813 - val_loss: 0.3769 - val_accuracy: 0.9257
# Epoch 113/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0533 - accuracy: 0.9813 - val_loss: 0.3763 - val_accuracy: 0.9255
# Epoch 114/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0530 - accuracy: 0.9813 - val_loss: 0.3804 - val_accuracy: 0.9254
# Epoch 115/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0525 - accuracy: 0.9814 - val_loss: 0.3723 - val_accuracy: 0.9268
# Epoch 116/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0516 - accuracy: 0.9818 - val_loss: 0.3777 - val_accuracy: 0.9262
# Epoch 117/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0524 - accuracy: 0.9814 - val_loss: 0.3725 - val_accuracy: 0.9260
# Epoch 118/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0519 - accuracy: 0.9816 - val_loss: 0.3815 - val_accuracy: 0.9258
# Epoch 119/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0513 - accuracy: 0.9819 - val_loss: 0.3752 - val_accuracy: 0.9262
# Epoch 120/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0506 - accuracy: 0.9821 - val_loss: 0.3783 - val_accuracy: 0.9264
# Epoch 121/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0509 - accuracy: 0.9821 - val_loss: 0.3801 - val_accuracy: 0.9259
# Epoch 122/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0500 - accuracy: 0.9824 - val_loss: 0.3939 - val_accuracy: 0.9246
# Epoch 123/123
# 785/785 [==============================] - 9s 12ms/step - loss: 0.0503 - accuracy: 0.9822 - val_loss: 0.3727 - val_accuracy: 0.9268

# %%
model.save("9268_BinaryTest_v05.h5")

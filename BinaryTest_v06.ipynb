# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime
from numpy import array
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 24.5 MB/s
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 590 kB/s
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70
# Collecting yahooquery
#   Downloading yahooquery-2.2.15-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 3.3 MB/s
# Collecting requests-futures>=1.0.0
#   Downloading requests_futures-1.0.0-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.3.5)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.64.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yahooquery) (1.15.0)
# Requirement already satisfied: requests>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from requests-futures>=1.0.0->yahooquery) (2.27.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2021.10.8)
# Installing collected packages: requests-futures, yahooquery
# Successfully installed requests-futures-1.0.0 yahooquery-2.2.15

# %%
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
  #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
    'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in','all_cryptocurrencies_us']
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(11,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-12][0],
                df[each-12][3],
                df[each-12][4],
                df[each-11][0],
                df[each-11][3],
                df[each-11][4],
                df[each-10][0],
                df[each-10][3],
                df[each-10][4],
                df[each-9][0],
                df[each-9][3],
                df[each-9][4],
                df[each-8][0],
                df[each-8][3],
                df[each-8][4],
                df[each-7][0],
                df[each-7][3],
                df[each-7][4],
                df[each-6][0],
                df[each-6][3],
                df[each-6][4],
                df[each-5][0],
                df[each-5][3],
                df[each-5][4],
                df[each-4][0],
                df[each-4][3],
                df[each-4][4],
                df[each-3][0],
                df[each-3][3],
                df[each-3][4],
                df[each-2][0],
                df[each-2][3],
                df[each-2][4],
                df[each-1][0],
                df[each-1][3],
                df[each-1][4],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object)
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled)
  df_scaled["suggestion"] = last_column
  return df_scaled
def stick_dfs(dfs):
  dataframe = dfs[0]
  for i in range(1,len(dfs)):
     dataframe = pd.concat([dataframe,dfs[i]], ignore_index = True)
  dataframe = dataframe.dropna()
  dataframe = dataframe.astype(float)
  return dataframe
def process(dfs): 
   fixed_dfs = []
   for df in dfs:
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df)
      df = row_scaler(df)
      #df = column_scaler(df)
      fixed_dfs.append(df)
   df = stick_dfs(fixed_dfs)
   return df

# %%
#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]

symbols = get_crypto_syms()
#symbols = read_syms_from_txt()
dfs = []
for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
             print("Passing...")
           else:
               dfs.append(data)
ndfs = dfs
dfs = []
for df in ndfs:
        if df.shape[0] > 13:
          dfs.append(df)

data = process(dfs)
xTrain, xTest, yTrain, yTest = spliting(data)
data

# %%
from google.colab import drive
drive.mount("/content/drive")

data = df.read_csv("/content/drive/MyDrive/Colab Files/df_BinaryTesting02.csv")
# Out:
#                  0         1         2         3         4         5  \
# 0        10.000000  9.962342  9.962342  1.011749  1.011339  1.011339
# 1        10.000000  9.725496  9.725496  9.666847  5.515231  5.515231
# 2        10.000000  5.736592  5.736592  5.693888  2.277124  2.277124
# 3         7.035992  2.642286  2.642286  2.622124  4.954872  4.954872
# 4         2.622124  4.954872  4.954872  4.820620  3.236222  3.236222
# ...            ...       ...       ...       ...       ...       ...
# 1765264   1.642061  3.063500  3.063500  3.061348  1.052867  1.052867
# 1765265   3.937438  2.182552  2.182552  2.183959  2.136360  2.136360
# 1765266   2.183959  2.136360  2.136360  2.138111  2.463915  2.463915
# 1765267   2.138111  2.463915  2.463915  2.463166  6.006860  6.006860
# 1765268   2.463166  6.006860  6.006860  6.011186  2.630554  2.630554
#
#                 6         7         8         9  ...        27         28  \
# 0        1.011252  1.005053  1.005053  1.004991  ...  1.005890   1.004207
# 1        5.473647  2.146474  2.146474  2.131205  ...  4.930512   4.281240
# 2        2.261444  4.075505  4.075505  3.971105  ...  4.356526   3.832417
# 3        4.820620  3.236222  3.236222  3.281911  ...  4.634102   1.128308
# 4        3.281911  4.226854  4.226854  4.216962  ...  1.085915   1.000000
# ...           ...       ...       ...       ...  ...       ...        ...
# 1765264  1.054477  1.000000  1.000000  1.002004  ...  3.074995   8.558728
# 1765265  2.138111  2.463915  2.463915  2.463166  ...  8.740223  10.000000
# 1765266  2.463166  6.006860  6.006860  6.011186  ...  9.999899   6.141116
# 1765267  6.011186  2.630554  2.630554  2.630223  ...  6.140918   1.000000
# 1765268  2.630223  3.048352  3.048352  3.047308  ...  1.000924   3.114194
#
#                 29        30         31         32        33        34  \
# 0         1.004207  1.004180   1.003210   1.003210  1.003046  1.002284
# 1         4.281240  4.171352   3.660986   3.660986  3.654794  1.000000
# 2         3.832417  3.826059   1.099779   1.099779  1.066812  1.000000
# 3         1.128308  1.085915   1.000000   1.000000  1.104318  2.741943
# 4         1.000000  1.104318   2.741943   2.741943  2.822847  2.140218
# ...            ...       ...        ...        ...       ...       ...
# 1765264   8.558728  8.558176  10.000000  10.000000  9.999884  5.583475
# 1765265  10.000000  9.999899   6.141116   6.141116  6.140918  1.000000
# 1765266   6.141116  6.140918   1.000000   1.000000  1.000924  3.114194
# 1765267   1.000000  1.000924   3.114194   3.114194  3.114139  5.564232
# 1765268   3.114194  3.114139   5.564232   5.564232  5.563657  1.767651
#
#                35  suggestion
# 0        1.002284         0.0
# 1        1.000000         0.0
# 2        1.000000         1.0
# 3        2.741943         0.0
# 4        2.140218         0.0
# ...           ...         ...
# 1765264  5.583475         0.0
# 1765265  1.000000         1.0
# 1765266  3.114194         1.0
# 1765267  5.564232         0.0
# 1765268  1.767651         0.0
#
# [1765269 rows x 37 columns]

# %%
model = Sequential()


model.add(Dense(1000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(750, activation='relu'))
model.add(Dense(500, activation='relu'))
model.add(Dense(250, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_80 (Dense)            (None, 1000)              37000
#
#  dense_81 (Dense)            (None, 750)               750750
#
#  dense_82 (Dense)            (None, 500)               375500
#
#  dense_83 (Dense)            (None, 250)               125250
#
#  dense_84 (Dense)            (None, 1)                 251
#
# =================================================================
# Total params: 1,288,751
# Trainable params: 1,288,751
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=123,batch_size=1024,validation_data=(xTest,yTest))
# Out:
# Epoch 1/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.6884 - accuracy: 0.5445 - val_loss: 0.6797 - val_accuracy: 0.5615
# Epoch 2/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.6701 - accuracy: 0.5771 - val_loss: 0.6624 - val_accuracy: 0.5890
# Epoch 3/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.6449 - accuracy: 0.6101 - val_loss: 0.6341 - val_accuracy: 0.6210
# Epoch 4/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.6187 - accuracy: 0.6391 - val_loss: 0.6105 - val_accuracy: 0.6479
# Epoch 5/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0
123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.1007 - accuracy: 0.9641 - val_loss: 0.3594 - val_accuracy: 0.9122
# Epoch 65/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0998 - accuracy: 0.9643 - val_loss: 0.3606 - val_accuracy: 0.9130
# Epoch 66/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0983 - accuracy: 0.9650 - val_loss: 0.3659 - val_accuracy: 0.9124
# Epoch 67/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0974 - accuracy: 0.9654 - val_loss: 0.3602 - val_accuracy: 0.9138
# Epoch 68/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0966 - accuracy: 0.9656 - val_loss: 0.3621 - val_accuracy: 0.9140
# Epoch 69/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0953 - accuracy: 0.9660 - val_loss: 0.3746 - val_accuracy: 0.9098
# Epoch 70/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0953 - accuracy: 0.9663 - val_loss: 0.3632 - val_accuracy: 0.9149
# Epoch 71/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0943 - accuracy: 0.9666 - val_loss: 0.3658 - val_accuracy: 0.9147
# Epoch 72/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0927 - accuracy: 0.9671 - val_loss: 0.3732 - val_accuracy: 0.9137
# Epoch 73/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0927 - accuracy: 0.9670 - val_loss: 0.3720 - val_accuracy: 0.9126
# Epoch 74/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0912 - accuracy: 0.9677 - val_loss: 0.3678 - val_accuracy: 0.9147
# Epoch 75/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0904 - accuracy: 0.9679 - val_loss: 0.3704 - val_accuracy: 0.9155
# Epoch 76/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0900 - accuracy: 0.9680 - val_loss: 0.3659 - val_accuracy: 0.9173
# Epoch 77/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0889 - accuracy: 0.9687 - val_loss: 0.3755 - val_accuracy: 0.9143
# Epoch 78/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0884 - accuracy: 0.9687 - val_loss: 0.3675 - val_accuracy: 0.9169
# Epoch 79/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0880 - accuracy: 0.9690 - val_loss: 0.3758 - val_accuracy: 0.9147
# Epoch 80/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0873 - accuracy: 0.9692 - val_loss: 0.3721 - val_accuracy: 0.9171
# Epoch 81/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0860 - accuracy: 0.9695 - val_loss: 0.3759 - val_accuracy: 0.9167
# Epoch 82/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0856 - accuracy: 0.9698 - val_loss: 0.3769 - val_accuracy: 0.9157
# Epoch 83/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0850 - accuracy: 0.9700 - val_loss: 0.3750 - val_accuracy: 0.9170
# Epoch 84/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0856 - accuracy: 0.9697 - val_loss: 0.3763 - val_accuracy: 0.9164
# Epoch 85/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0835 - accuracy: 0.9707 - val_loss: 0.3785 - val_accuracy: 0.9173
# Epoch 86/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0837 - accuracy: 0.9705 - val_loss: 0.3702 - val_accuracy: 0.9193
# Epoch 87/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0832 - accuracy: 0.9707 - val_loss: 0.3788 - val_accuracy: 0.9166
# Epoch 88/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0816 - accuracy: 0.9714 - val_loss: 0.3793 - val_accuracy: 0.9175
# Epoch 89/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0816 - accuracy: 0.9713 - val_loss: 0.3751 - val_accuracy: 0.9181
# Epoch 90/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0805 - accuracy: 0.9718 - val_loss: 0.3845 - val_accuracy: 0.9165
# Epoch 91/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0809 - accuracy: 0.9715 - val_loss: 0.3802 - val_accuracy: 0.9178
# Epoch 92/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0799 - accuracy: 0.9718 - val_loss: 0.3804 - val_accuracy: 0.9177
# Epoch 93/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0796 - accuracy: 0.9719 - val_loss: 0.3838 - val_accuracy: 0.9184
# Epoch 94/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0795 - accuracy: 0.9722 - val_loss: 0.3827 - val_accuracy: 0.9186
# Epoch 95/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0785 - accuracy: 0.9725 - val_loss: 0.3804 - val_accuracy: 0.9194
# Epoch 96/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0783 - accuracy: 0.9726 - val_loss: 0.3800 - val_accuracy: 0.9202
# Epoch 97/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0775 - accuracy: 0.9728 - val_loss: 0.3911 - val_accuracy: 0.9181
# Epoch 98/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0773 - accuracy: 0.9728 - val_loss: 0.3896 - val_accuracy: 0.9193
# Epoch 99/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0771 - accuracy: 0.9731 - val_loss: 0.3892 - val_accuracy: 0.9191
# Epoch 100/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0765 - accuracy: 0.9733 - val_loss: 0.3932 - val_accuracy: 0.9175
# Epoch 101/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0758 - accuracy: 0.9734 - val_loss: 0.3922 - val_accuracy: 0.9188
# Epoch 102/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0758 - accuracy: 0.9735 - val_loss: 0.3884 - val_accuracy: 0.9185
# Epoch 103/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0753 - accuracy: 0.9737 - val_loss: 0.3940 - val_accuracy: 0.9167
# Epoch 104/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0750 - accuracy: 0.9737 - val_loss: 0.3884 - val_accuracy: 0.9201
# Epoch 105/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0743 - accuracy: 0.9740 - val_loss: 0.3948 - val_accuracy: 0.9201
# Epoch 106/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0737 - accuracy: 0.9743 - val_loss: 0.4010 - val_accuracy: 0.9193
# Epoch 107/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0739 - accuracy: 0.9742 - val_loss: 0.3991 - val_accuracy: 0.9189
# Epoch 108/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0728 - accuracy: 0.9747 - val_loss: 0.4015 - val_accuracy: 0.9190
# Epoch 109/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0730 - accuracy: 0.9745 - val_loss: 0.4013 - val_accuracy: 0.9187
# Epoch 110/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0725 - accuracy: 0.9749 - val_loss: 0.3946 - val_accuracy: 0.9195
# Epoch 111/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0724 - accuracy: 0.9748 - val_loss: 0.3988 - val_accuracy: 0.9197
# Epoch 112/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0715 - accuracy: 0.9752 - val_loss: 0.3985 - val_accuracy: 0.9201
# Epoch 113/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0715 - accuracy: 0.9752 - val_loss: 0.4086 - val_accuracy: 0.9183
# Epoch 114/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0709 - accuracy: 0.9753 - val_loss: 0.4079 - val_accuracy: 0.9185
# Epoch 115/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0706 - accuracy: 0.9755 - val_loss: 0.4046 - val_accuracy: 0.9190
# Epoch 116/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0711 - accuracy: 0.9754 - val_loss: 0.4008 - val_accuracy: 0.9211
# Epoch 117/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0705 - accuracy: 0.9756 - val_loss: 0.4041 - val_accuracy: 0.9201
# Epoch 118/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0697 - accuracy: 0.9759 - val_loss: 0.4069 - val_accuracy: 0.9186
# Epoch 119/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0698 - accuracy: 0.9759 - val_loss: 0.4075 - val_accuracy: 0.9193
# Epoch 120/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0695 - accuracy: 0.9760 - val_loss: 0.4043 - val_accuracy: 0.9224
# Epoch 121/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0691 - accuracy: 0.9759 - val_loss: 0.4181 - val_accuracy: 0.9189
# Epoch 122/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0690 - accuracy: 0.9760 - val_loss: 0.4103 - val_accuracy: 0.9203
# Epoch 123/123
# 1552/1552 [==============================] - 8s 5ms/step - loss: 0.0689 - accuracy: 0.9762 - val_loss: 0.4105 - val_accuracy: 0.9197

# %%
model.save("9268_BinaryTest_v05.h5")

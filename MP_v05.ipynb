# %% [markdown]
# <a href="https://colab.research.google.com/github/aliprg0/Google_Colab/blob/main/MP_v05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime
import random
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: yahooquery in /usr/local/lib/python3.7/dist-packages (2.2.15)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.64.0)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.3.5)
# Requirement already satisfied: requests-futures>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (1.21.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yahooquery) (1.15.0)
# Requirement already satisfied: requests>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from requests-futures>=1.0.0->yahooquery) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.10)

# %%
clmns = ['15 Open', '15 High', '15 Low', '15 Close', '15 Volume', '14 Open', '14 High', '14 Low', '14 Close', '14 Volume', '13 Open', '13 High', '13 Low', '13 Close', '13 Volume', '12 Open', '12 High', '12 Low', '12 Close', '12 Volume', '11 Open', '11 High', '11 Low', '11 Close', '11 Volume', '10 Open', '10 High', '10 Low', '10 Close', '10 Volume', '9 Open', '9 High', '9 Low', '9 Close', '9 Volume', '8 Open', '8 High', '8 Low', '8 Close', '8 Volume', '7 Open', '7 High', '7 Low', '7 Close', '7 Volume', '6 Open', '6 High', '6 Low', '6 Close', '6 Volume', '5 Open', '5 High', '5 Low', '5 Close', '5 Volume', '4 Open', '4 High', '4 Low', '4 Close', '4 Volume', '3 Open', '3 High', '3 Low', '3 Close', '3 Volume', '2 Open', '2 High', '2 Low', '2 Close', '2 Volume', '1 Open', '1 High', '1 Low', '1 Close', '1 Volume',"suggestion"]
clmnsws = ['15 Open', '15 High', '15 Low', '15 Close', '15 Volume', '14 Open', '14 High', '14 Low', '14 Close', '14 Volume', '13 Open', '13 High', '13 Low', '13 Close', '13 Volume', '12 Open', '12 High', '12 Low', '12 Close', '12 Volume', '11 Open', '11 High', '11 Low', '11 Close', '11 Volume', '10 Open', '10 High', '10 Low', '10 Close', '10 Volume', '9 Open', '9 High', '9 Low', '9 Close', '9 Volume', '8 Open', '8 High', '8 Low', '8 Close', '8 Volume', '7 Open', '7 High', '7 Low', '7 Close', '7 Volume', '6 Open', '6 High', '6 Low', '6 Close', '6 Volume', '5 Open', '5 High', '5 Low', '5 Close', '5 Volume', '4 Open', '4 High', '4 Low', '4 Close', '4 Volume', '3 Open', '3 High', '3 Low', '3 Close', '3 Volume', '2 Open', '2 High', '2 Low', '2 Close', '2 Volume', '1 Open', '1 High', '1 Low', '1 Close', '1 Volume']
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
   #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
   'all_cryptocurrencies_us','all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',]
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(15,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-15][0],
                df[each-15][1],
                df[each-15][2],
                df[each-15][3],
                df[each-15][4],
                df[each-14][0],
                df[each-14][1],
                df[each-14][2],
                df[each-14][3],
                df[each-14][4],
                df[each-13][0],
                df[each-13][1],
                df[each-13][2],
                df[each-13][3],
                df[each-13][4],
                df[each-12][0],
                df[each-12][1],
                df[each-12][2],
                df[each-12][3],
                df[each-12][4],
                df[each-11][0],
                df[each-11][1],
                df[each-11][2],
                df[each-11][3],
                df[each-11][4],
                df[each-10][0],
                df[each-10][1],
                df[each-10][2],
                df[each-10][3],
                df[each-10][4],
                df[each-9][0],
                df[each-9][1],
                df[each-9][2],
                df[each-9][3],
                df[each-9][4],
                df[each-8][0],
                df[each-8][1],
                df[each-8][2],
                df[each-8][3],
                df[each-8][4],
                df[each-7][0],
                df[each-7][1],
                df[each-7][2],
                df[each-7][3],
                df[each-7][4],
                df[each-6][0],
                df[each-6][1],
                df[each-6][2],
                df[each-6][3],
                df[each-6][4],
                df[each-5][0],
                df[each-5][1],
                df[each-5][2],
                df[each-5][3],
                df[each-5][4],
                df[each-4][0],
                df[each-4][1],
                df[each-4][2],
                df[each-4][3],
                df[each-4][4],
                df[each-3][0],
                df[each-3][1],
                df[each-3][2],
                df[each-3][3],
                df[each-3][4],
                df[each-2][0],
                df[each-2][1],
                df[each-2][2],
                df[each-2][3],
                df[each-2][4],
                df[each-1][0],
                df[each-1][2],
                df[each-1][1],
                df[each-1][3],
                df[each-1][4],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,10))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object,columns = clmnsws)
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled,columns = clmnsws)
  df_scaled["suggestion"] = last_column
  return df_scaled
def process(df): 
      df = df.dropna()
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df,columns = clmns)
      df = row_scaler(df)
      #df = column_scaler(df)
      return df

# %%
def get_data(symbols):
    unattached_dfs = []
    for symbol in symbols:
           data = yf.download(symbol,period="730d",interval="1h",progress=False)
           if data.empty :
              pass
           else:
               if data.shape[0] > 14:
                   unattached_dfs.append(process(data))
    symbols = []
    symbol = []
    data = []

    data = pd.concat(unattached_dfs)
    data = data.astype(float)

    xTrain, xTest, yTrain, yTest = spliting(data)
    print(data.shape)
    data.to_csv(f"{random.randint(1,10000)}.csv")
    data = []
    return xTrain, xTest, yTrain, yTest

#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]
symbols = read_syms_from_txt()
#symbols = get_crypto_syms()

pieces = 10
new_arrays = np.array_split(symbols, pieces)
for symbols in new_arrays:
   xTrain, xTest, yTrain, yTest= get_data(symbols)
# Out:
# 1 Failed download:
# - TXG: 1h data not available for startTime=1568295000 and endTime=1650371168. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - PIH: No data found, symbol may be delisted
#
# 1 Failed download:
# - PIHPP: No data found, symbol may be delisted
#
# 1 Failed download:
# - ONEM: 1h data not available for startTime=1580481000 and endTime=1650371172. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - FCCY: No data found, symbol may be delisted
#
# 1 Failed download:
# - KRKR: 1h data not available for startTime=1573223400 and endTime=1650371175. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ETNB: 1h data not available for startTime=1573482600 and endTime=1650371176. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - JFK: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFKKR: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFKKU: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFKKW: No data found, symbol may be delisted
#
# 1 Failed download:
# - JFU: 1h data not available for startTime=1565875800 and endTime=1650371178. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ACIA: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACAM: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACAMU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACAMW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACCP: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - XLRN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ACLL: No data found, symbol may be delisted
#
# 1 Failed download:
# - ADMS: No data found, symbol may be delisted
#
# 1 Failed download:
# - ADPT: 1h data not available for startTime=1561642200 and endTime=1650371198. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ADXN: 1h data not available for startTime=1581517800 and endTime=1650371198. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ADRO: No data found, symbol may be delisted
#
# 1 Failed download:
# - DWEQ: 1h data not available for startTime=1577457000 and endTime=1650371204. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - DWAW: 1h data not available for startTime=1577457000 and endTime=1650371204. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - DWUS: 1h data not available for startTime=1577457000 and endTime=1650371204. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AEGN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARPO: No data found, symbol may be delisted
#
# 1 Failed download:
# - AIH: 1h data not available for startTime=1572010200 and endTime=1650371207. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AFYA: 1h data not available for startTime=1563543000 and endTime=1650371209. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AGBA: 1h data not available for startTime=1564579800 and endTime=1650371209. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AGNCO: 1h data not available for startTime=1569591000 and endTime=1650371213. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AGNCP: 1h data not available for startTime=1580913000 and endTime=1650371213. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AGFSW: No data found, symbol may be delisted
#
# 1 Failed download:
# - AIMT: No data found, symbol may be delisted
#
# 1 Failed download:
# - AIRTP: 1h data not available for startTime=1560432600 and endTime=1650371216. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AIRTW: No data found, symbol may be delisted
#
# 1 Failed download:
# - AKCA: No data found, symbol may be delisted
#
# 1 Failed download:
# - AKRO: 1h data not available for startTime=1561037400 and endTime=1650371221. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AKER: No data found, symbol may be delisted
#
# 1 Failed download:
# - ALSK: No data found, symbol may be delisted
#
# 1 Failed download:
# - ALXN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ALIM: 1h data not available for startTime=1572877800 and endTime=1650371226. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ALTA: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMAG: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMTBB: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMRH: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMRHW: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMRB: No data found, symbol may be delisted
#
# 1 Failed download:
# - ASRVP: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMHC: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMHCU: No data found, symbol may be delisted
#
# 1 Failed download:
# - AMHCW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANCN: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDA: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDAR: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANDAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ANPC: 1h data not available for startTime=1580481000 and endTime=1650371265. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - APEX: No data found, symbol may be delisted
#
# 1 Failed download:
# - APXT: No data found, symbol may be delisted
#
# 1 Failed download:
# - APXTU: No data found, symbol may be delisted
#
# 1 Failed download:
# - APXTW: No data found, symbol may be delisted
#
# 1 Failed download:
# - APHA: No data found, symbol may be delisted
#
# 1 Failed download:
# - APRE: 1h data not available for startTime=1570109400 and endTime=1650371274. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ARQT: 1h data not available for startTime=1580481000 and endTime=1650371300. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ARTL: 1h data not available for startTime=1561123800 and endTime=1650371316. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AACQU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARYB: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARYBU: No data found, symbol may be delisted
#
# 1 Failed download:
# - ARYBW: No data found, symbol may be delisted
#
# 1 Failed download:
# - ASNA: No data found, symbol may be delisted
#
# 1 Failed download:
# - ASFI: No data found, symbol may be delisted
#
# 1 Failed download:
# - AFH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ATCXW: No data found, symbol may be delisted
#
# 1 Failed download:
# - BCEL: 1h data not available for startTime=1561037400 and endTime=1650371372. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - EARS: No data found, symbol may be delisted
# (1157546, 75) (1157546,)
# (128617, 75) (128617,)
# (1286163, 76)
#
# 1 Failed download:
# - AAXN: No data found, symbol may be delisted
#
# 1 Failed download:
# - AXGT: No data found, symbol may be delisted
#
# 1 Failed download:
# - AZRX: No data found, symbol may be delisted
#
# 1 Failed download:
# - BCOM: No data found, symbol may be delisted
#
# 1 Failed download:
# - RILYH: No data found, symbol may be delisted
#
# 1 Failed download:
# - RILYM: 1h data not available for startTime=1581604200 and endTime=1650371576. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - RILYN: 1h data not available for startTime=1569331800 and endTime=1650371576. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - RILYP: 1h data not available for startTime=1570195800 and endTime=1650371576. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BOCH: No data found, symbol may be delisted
#
# 1 Failed download:
# - BMLP: 1h data not available for startTime=1581517800 and endTime=1650371580. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - ZTEST: No data found, symbol may be delisted
#
# 1 Failed download:
# - BXRX: 1h data not available for startTime=1573741800 and endTime=1650371589. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BEAM: 1h data not available for startTime=1580999400 and endTime=1650371591. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BFYT: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPA: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPAR: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRPAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - BASI: No data found, symbol may be delisted
#
# 1 Failed download:
# - BHTG: No data found, symbol may be delisted
#
# 1 Failed download:
# - BNTX: 1h data not available for startTime=1570714200 and endTime=1650371611. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BSTC: No data found, symbol may be delisted
#
# 1 Failed download:
# - BDTX: 1h data not available for startTime=1580481000 and endTime=1650371613. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BHAT: 1h data not available for startTime=1564147800 and endTime=1650371618. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BMCH: No data found, symbol may be delisted
#
# 1 Failed download:
# - BSBK: 1h data not available for startTime=1579185000 and endTime=1650371622. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - WIFI: No data found, symbol may be delisted
#
# 1 Failed download:
# - BOKFL: No data found, symbol may be delisted
#
# 1 Failed download:
# - BPFH: No data found, symbol may be delisted
#
# 1 Failed download:
# - BBRX: No data found, symbol may be delisted
#
# 1 Failed download:
# - BDGE: No data found, symbol may be delisted
#
# 1 Failed download:
# - BBIO: 1h data not available for startTime=1561642200 and endTime=1650371629. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - AVGOP: 1h data not available for startTime=1569418200 and endTime=1650371634. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BPY: No data found, symbol may be delisted
#
# 1 Failed download:
# - BPYPN: 1h data not available for startTime=1581431400 and endTime=1650371636. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BPYPO: 1h data not available for startTime=1566394200 and endTime=1650371636. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BPYU: No data found, symbol may be delisted
#
# 1 Failed download:
# - BPYUP: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRKS: No data found, symbol may be delisted
#
# 1 Failed download:
# - BRP: 1h data not available for startTime=1571923800 and endTime=1650371637. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - BMTC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CABA: 1h data not available for startTime=1572010200 and endTime=1650371640. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CPZ: 1h data not available for startTime=1574778600 and endTime=1650371645. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CMBM: 1h data not available for startTime=1561555800 and endTime=1650371658. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CAN: 1h data not available for startTime=1574260200 and endTime=1650371663. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CGIX: No data found, symbol may be delisted
#
# 1 Failed download:
# - CSWCL: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPTA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPST: No data found, symbol may be delisted
#
# 1 Failed download:
# - CATM: No data found, symbol may be delisted
#
# 1 Failed download:
# - CSTL: 1h data not available for startTime=1564061400 and endTime=1650371709. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CATB: No data found, symbol may be delisted
#
# 1 Failed download:
# - APOP: No data found, symbol may be delisted
#
# 1 Failed download:
# - APOPW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLRBZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - CBMG: No data found, symbol may be delisted
#
# 1 Failed download:
# - CETXW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CNTG: 1h data not available for startTime=1573137000 and endTime=1650371747. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CETV: No data found, symbol may be delisted
#
# 1 Failed download:
# - CNBKA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CERC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CRNC: 1h data not available for startTime=1568640600 and endTime=1650371759. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CFFA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CFFAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CFFAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CHNG: 1h data not available for startTime=1561642200 and endTime=1650371767. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CHNGU: 1h data not available for startTime=1561642200 and endTime=1650371767. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CHFS: No data found, symbol may be delisted
#
# 1 Failed download:
# - CBPO: No data found, symbol may be delisted
#
# 1 Failed download:
# - CCCL: No data found, symbol may be delisted
#
# 1 Failed download:
# - CCRC: No data found, symbol may be delisted
#
# 1 Failed download:
# - JRJC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CIH: 1h data not available for startTime=1560432600 and endTime=1650371797. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - PLIN: 1h data not available for startTime=1565789400 and endTime=1650371810. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CHPM: 1h data not available for startTime=1578666600 and endTime=1650371814. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CHPMU: 1h data not available for startTime=1574433000 and endTime=1650371814. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CIIC: No data found, symbol may be delisted
#
# 1 Failed download:
# - CIICU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CIICW: No data found, symbol may be delisted
# (1074870, 75) (1074870,)
# (119431, 75) (119431,)
# (1194301, 76)
#
# 1 Failed download:
# - CBLI: No data found, symbol may be delisted
#
# 1 Failed download:
# - CNSP: 1h data not available for startTime=1573223400 and endTime=1650372007. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CGRO: No data found, symbol may be delisted
#
# 1 Failed download:
# - CGROU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CGROW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLCT: No data found, symbol may be delisted
#
# 1 Failed download:
# - HHT: No data found, symbol may be delisted
#
# 1 Failed download:
# - CBSHP: No data found, symbol may be delisted
#
# 1 Failed download:
# - ESXB: No data found, symbol may be delisted
#
# 1 Failed download:
# - CFBI: No data found, symbol may be delisted
#
# 1 Failed download:
# - CDOR: No data found, symbol may be delisted
#
# 1 Failed download:
# - CNST: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPTI: No data found for this date range, symbol may be delisted
#
# 1 Failed download:
# - CORE: No data found, symbol may be delisted
#
# 1 Failed download:
# - CSOD: No data found, symbol may be delisted
#
# 1 Failed download:
# - CLDB: No data found, symbol may be delisted
#
# 1 Failed download:
# - CPAH: No data found, symbol may be delisted
#
# 1 Failed download:
# - ICBK: No data found, symbol may be delisted
#
# 1 Failed download:
# - COWNZ: No data found, symbol may be delisted
#
# 1 Failed download:
# - BREW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CREE: No data found, symbol may be delisted
#
# 1 Failed download:
# - CRSA: No data found, symbol may be delisted
#
# 1 Failed download:
# - CRSAU: No data found, symbol may be delisted
#
# 1 Failed download:
# - CRSAW: No data found, symbol may be delisted
#
# 1 Failed download:
# - CCAP: 1h data not available for startTime=1580740200 and endTime=1650372043. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CFB: 1h data not available for startTime=1565875800 and endTime=1650372047. The requested range must be within the last 730 days.
#
# 1 Failed download:
# - CRWD: 1h data not available for startTime=1560346200 and endTime=1650372047. The requested range must be within the last 730 days.

# %%
model = Sequential()

model.add(Dense(2000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(1000, activation='relu'))
model.add(Dense(750, activation='relu'))
model.add(Dense(500, activation='relu'))
model.add(Dense(256, activation='relu'))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
model.summary()

# %%
model.fit(xTrain,yTrain,epochs=50,batch_size=8192,validation_data=(xTest,yTest))

# %%
from google.colab import drive
drive.mount("/content/drive")

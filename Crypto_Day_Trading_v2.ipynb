# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime
import random
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 45.2 MB/s
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70
# Collecting yahooquery
#   Downloading yahooquery-2.2.15-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.5 MB/s
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.64.0)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.8.0)
# Collecting requests-futures>=1.0.0
#   Downloading requests_futures-1.0.0-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.3.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2018.9)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (1.21.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yahooquery) (1.15.0)
# Requirement already satisfied: requests>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from requests-futures>=1.0.0->yahooquery) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2021.10.8)
# Installing collected packages: requests-futures, yahooquery
# Successfully installed requests-futures-1.0.0 yahooquery-2.2.15

# %%
clmns = [ '12 Open', '12 High', '12 Low', '12 Close', '12 Volume', '11 Open', '11 High', '11 Low', '11 Close', '11 Volume', '10 Open', '10 High', '10 Low', '10 Close', '10 Volume', '9 Open', '9 High', '9 Low', '9 Close', '9 Volume', '8 Open', '8 High', '8 Low', '8 Close', '8 Volume', '7 Open', '7 High', '7 Low', '7 Close', '7 Volume', '6 Open', '6 High', '6 Low', '6 Close', '6 Volume', '5 Open', '5 High', '5 Low', '5 Close', '5 Volume', '4 Open', '4 High', '4 Low', '4 Close', '4 Volume', '3 Open', '3 High', '3 Low', '3 Close', '3 Volume', '2 Open', '2 High', '2 Low', '2 Close', '2 Volume', '1 Open', '1 High', '1 Low', '1 Close', '1 Volume',"suggestion"]
clmnsws = ['12 Open', '12 High', '12 Low', '12 Close', '12 Volume', '11 Open', '11 High', '11 Low', '11 Close', '11 Volume', '10 Open', '10 High', '10 Low', '10 Close', '10 Volume', '9 Open', '9 High', '9 Low', '9 Close', '9 Volume', '8 Open', '8 High', '8 Low', '8 Close', '8 Volume', '7 Open', '7 High', '7 Low', '7 Close', '7 Volume', '6 Open', '6 High', '6 Low', '6 Close', '6 Volume', '5 Open', '5 High', '5 Low', '5 Close', '5 Volume', '4 Open', '4 High', '4 Low', '4 Close', '4 Volume', '3 Open', '3 High', '3 Low', '3 Close', '3 Volume', '2 Open', '2 High', '2 Low', '2 Close', '2 Volume', '1 Open', '1 High', '1 Low', '1 Close', '1 Volume']
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
   #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
   'all_cryptocurrencies_us','all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',]
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(13,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-12][0],
                df[each-12][1],
                df[each-12][2],
                df[each-12][3],
                df[each-12][4],
                df[each-11][0],
                df[each-11][1],
                df[each-11][2],
                df[each-11][3],
                df[each-11][4],
                df[each-10][0],
                df[each-10][1],
                df[each-10][2],
                df[each-10][3],
                df[each-10][4],
                df[each-9][0],
                df[each-9][1],
                df[each-9][2],
                df[each-9][3],
                df[each-9][4],
                df[each-8][0],
                df[each-8][1],
                df[each-8][2],
                df[each-8][3],
                df[each-8][4],
                df[each-7][0],
                df[each-7][1],
                df[each-7][2],
                df[each-7][3],
                df[each-7][4],
                df[each-6][0],
                df[each-6][1],
                df[each-6][2],
                df[each-6][3],
                df[each-6][4],
                df[each-5][0],
                df[each-5][1],
                df[each-5][2],
                df[each-5][3],
                df[each-5][4],
                df[each-4][0],
                df[each-4][1],
                df[each-4][2],
                df[each-4][3],
                df[each-4][4],
                df[each-3][0],
                df[each-3][1],
                df[each-3][2],
                df[each-3][3],
                df[each-3][4],
                df[each-2][0],
                df[each-2][1],
                df[each-2][2],
                df[each-2][3],
                df[each-2][4],
                df[each-1][0],
                df[each-1][2],
                df[each-1][1],
                df[each-1][3],
                df[each-1][4],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(-10,10))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object,columns = clmnsws)
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled,columns = clmnsws)
  df_scaled["suggestion"] = last_column
  return df_scaled
def process(df): 
      df = df.dropna()
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df,columns = clmns)
      df = row_scaler(df)
      #df = column_scaler(df)
      return df

# %%
def get_data(symbols):
    unattached_dfs = []
    for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
              pass
           else:
               if data.shape[0] > 14:
                   unattached_dfs.append(process(data))
    symbols = []
    symbol = []
    data = []

    data = pd.concat(unattached_dfs)
    data = data.astype(float)

    xTrain, xTest, yTrain, yTest = spliting(data)
    print(data.shape)
    data.to_csv(f"{random.randint(1,1000)}.csv")
    data = []
    return xTrain, xTest, yTrain, yTest

#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]
#symbols = read_syms_from_txt()
symbols = get_crypto_syms()

#pieces = 10
#new_arrays = np.array_split(symbols, pieces)
#for symbols in new_arrays:
#   xTrain, xTest, yTrain, yTest= get_data(symbols)
  
xTrain, xTest, yTrain, yTest= get_data(symbols)

# %%
data = pd.read_csv("/content/drive/MyDrive/day_trading_c_first_1010.csv")
data.drop("Unnamed: 0",axis=1,inplace=True)
xTrain, xTest, yTrain, yTest= spliting(data)
data
# Out:
# (1594467, 60) (1594467,)
# (177164, 60) (177164,)
#            12 Open    12 High    12 Low  12 Close  12 Volume   11 Open  \
# 0        10.000000  10.000000 -0.341759  2.337512   2.337512  2.257861
# 1         4.964004   6.040795 -6.453390 -3.491930  -3.491930 -3.527415
# 2        -3.527415   4.731159 -4.909474  0.578644   0.578644  0.342338
# 3         0.342338   1.594845 -3.957902 -2.330592  -2.330592 -2.250095
# 4        -0.145285   1.722377 -0.616025  0.584004   0.584004  0.569668
# ...            ...        ...       ...       ...        ...       ...
# 1771626   0.548238  10.000000  0.423195  3.151721   3.151721  3.141186
# 1771627   4.834520   9.138837  1.448070  4.515874   4.515874  4.505797
# 1771628   4.505797  10.000000 -0.699992  4.776881   4.776881  4.779354
# 1771629   6.824721   7.819951  2.243839  2.797684   2.797684  2.783473
# 1771630   2.783473   7.200726  0.423956  3.087227   3.087227  3.076234
#
#            11 High    11 Low  11 Close  11 Volume  ...    2 High      2 Low  \
# 0         3.139921 -7.094771 -4.668872  -4.668872  ... -3.198532  -9.505552
# 1         4.731159 -4.909474  0.578644   0.578644  ... -6.257482 -10.000000
# 2         1.594845 -3.957902 -2.330592  -2.330592  ... -4.593824  -9.652898
# 3         0.005045 -2.818498 -1.369502  -1.369502  ... -4.477833  -7.535956
# 4        10.000000 -0.838973  8.622184   8.622184  ... -3.395780  -6.394895
# ...            ...       ...       ...        ...  ...       ...        ...
# 1771626   6.954173  0.141293  2.858913   2.858913  ... -5.968128 -10.000000
# 1771627  10.000000 -0.699992  4.776881   4.776881  ... -1.151497  -6.813600
# 1771628   5.653594  0.755366  1.241880   1.241880  ... -2.524593  -9.701057
# 1771629   7.200726  0.423956  3.087227   3.087227  ... -1.056402  -8.315405
# 1771630  10.000000 -0.562500  0.398549   0.398549  ...  3.580812  -6.635931
#
#           2 Close  2 Volume    1 Open     1 High     1 Low   1 Close  \
# 0       -8.832189 -8.832189 -8.891983 -10.000000 -6.934292 -9.237291
# 1       -9.068910 -9.068910 -8.889732  -9.652898 -4.593824 -5.757460
# 2       -5.757460 -5.757460 -5.618100  -7.535956 -4.477833 -6.717978
# 3       -6.717978 -6.717978 -6.610351  -9.796291 -6.174960 -9.182884
# 4       -5.886883 -5.886883 -5.860835 -10.000000 -5.260102 -9.605012
# ...           ...       ...       ...        ...       ...       ...
# 1771626 -6.728336 -6.728336 -6.730836  -7.177322 -2.161538 -4.668241
# 1771627 -3.981206 -3.981206 -3.989121  -9.701057 -2.524593 -7.483741
# 1771628 -7.483741 -7.483741 -7.479560  -8.520200 -2.143668 -5.807096
# 1771629 -5.226825 -5.226825 -5.229366  -6.635931  3.580812  2.556608
# 1771630  2.556608  2.556608  2.590111  -3.204173  5.337695 -3.017086
#
#          1 Volume  suggestion
# 0       -9.237291         1.0
# 1       -5.757460         0.0
# 2       -6.717978         0.0
# 3       -9.182884         0.0
# 4       -9.605012         0.0
# ...           ...         ...
# 1771626 -4.668241         0.0
# 1771627 -7.483741         1.0
# 1771628 -5.807096         1.0
# 1771629  2.556608         0.0
# 1771630 -3.017086         1.0
#
# [1771631 rows x 61 columns]

# %%
model = Sequential()



model.add(Dense(1000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(1000, activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(1000, activation='relu'))

model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1000)              61000
#
#  dense_1 (Dense)             (None, 1000)              1001000
#
#  dense_2 (Dense)             (None, 1000)              1001000
#
#  dense_3 (Dense)             (None, 1000)              1001000
#
#  dense_4 (Dense)             (None, 1)                 1001
#
# =================================================================
# Total params: 3,065,001
# Trainable params: 3,065,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=50,batch_size=50000,validation_data=(xTest,yTest))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 443s 14s/step - loss: 0.9851 - accuracy: 0.5072 - val_loss: 0.6908 - val_accuracy: 0.5309
# Epoch 2/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6881 - accuracy: 0.5386 - val_loss: 0.6843 - val_accuracy: 0.5529
# Epoch 3/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6813 - accuracy: 0.5591 - val_loss: 0.6778 - val_accuracy: 0.5680
# Epoch 4/50
# 32/32 [==============================] - 436s 14s/step - loss: 0.6751 - accuracy: 0.5717 - val_loss: 0.6726 - val_accuracy: 0.5755
# Epoch 5/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6747 - accuracy: 0.5740 - val_loss: 0.6736 - val_accuracy: 0.5754
# Epoch 6/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6642 - accuracy: 0.5909 - val_loss: 0.6575 - val_accuracy: 0.6013
# Epoch 7/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6589 - accuracy: 0.5985 - val_loss: 0.6502 - val_accuracy: 0.6092
# Epoch 8/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6490 - accuracy: 0.6107 - val_loss: 0.6457 - val_accuracy: 0.6156
# Epoch 9/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6405 - accuracy: 0.6213 - val_loss: 0.6373 - val_accuracy: 0.6228
# Epoch 10/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6341 - accuracy: 0.6277 - val_loss: 0.6362 - val_accuracy: 0.6252
# Epoch 11/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6223 - accuracy: 0.6405 - val_loss: 0.6235 - val_accuracy: 0.6379
# Epoch 12/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6406 - accuracy: 0.6195 - val_loss: 0.6452 - val_accuracy: 0.6140
# Epoch 13/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6201 - accuracy: 0.6420 - val_loss: 0.6125 - val_accuracy: 0.6474
# Epoch 14/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6012 - accuracy: 0.6612 - val_loss: 0.6083 - val_accuracy: 0.6536
# Epoch 15/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.5935 - accuracy: 0.6687 - val_loss: 0.6015 - val_accuracy: 0.6609
# Epoch 16/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.5838 - accuracy: 0.6775 - val_loss: 0.5848 - val_accuracy: 0.6755
# Epoch 17/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.5681 - accuracy: 0.6916 - val_loss: 0.5729 - val_accuracy: 0.6847
# Epoch 18/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.5734 - accuracy: 0.6882 - val_loss: 0.6484 - val_accuracy: 0.6142
# Epoch 19/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.6035 - accuracy: 0.6579 - val_loss: 0.5799 - val_accuracy: 0.6804
# Epoch 20/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.5466 - accuracy: 0.7096 - val_loss: 0.5516 - val_accuracy: 0.7057
# Epoch 21/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.5303 - accuracy: 0.7230 - val_loss: 0.5370 - val_accuracy: 0.7192
# Epoch 22/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.5030 - accuracy: 0.7439 - val_loss: 0.5268 - val_accuracy: 0.7267
# Epoch 23/50
# 32/32 [==============================] - 434s 14s/step - loss: 0.5138 - accuracy: 0.7362 - val_loss: 0.5152 - val_accuracy: 0.7346
# Epoch 24/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.4698 - accuracy: 0.7677 - val_loss: 0.4951 - val_accuracy: 0.7520
# Epoch 25/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.4486 - accuracy: 0.7819 - val_loss: 0.4771 - val_accuracy: 0.7656
# Epoch 26/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.4261 - accuracy: 0.7967 - val_loss: 0.4738 - val_accuracy: 0.7683
# Epoch 27/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.3993 - accuracy: 0.8139 - val_loss: 0.5069 - val_accuracy: 0.7497
# Epoch 28/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.3740 - accuracy: 0.8293 - val_loss: 0.4144 - val_accuracy: 0.8099
# Epoch 29/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.3466 - accuracy: 0.8444 - val_loss: 0.3931 - val_accuracy: 0.8252
# Epoch 30/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.3192 - accuracy: 0.8598 - val_loss: 0.3767 - val_accuracy: 0.8366
# Epoch 31/50
# 32/32 [==============================] - 431s 13s/step - loss: 0.2960 - accuracy: 0.8725 - val_loss: 0.3589 - val_accuracy: 0.8459
# Epoch 32/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.2970 - accuracy: 0.8712 - val_loss: 0.3661 - val_accuracy: 0.8413
# Epoch 33/50
# 32/32 [==============================] - 433s 14s/step - loss: 0.2489 - accuracy: 0.8982 - val_loss: 0.3248 - val_accuracy: 0.8710
# Epoch 34/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.2457 - accuracy: 0.8977 - val_loss: 0.3285 - val_accuracy: 0.8682
# Epoch 35/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.2092 - accuracy: 0.9171 - val_loss: 0.3096 - val_accuracy: 0.8826
# Epoch 36/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.2034 - accuracy: 0.9185 - val_loss: 0.2986 - val_accuracy: 0.8886
# Epoch 37/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.1826 - accuracy: 0.9286 - val_loss: 0.3038 - val_accuracy: 0.8900
# Epoch 38/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.1736 - accuracy: 0.9323 - val_loss: 0.2881 - val_accuracy: 0.9002
# Epoch 39/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.1539 - accuracy: 0.9418 - val_loss: 0.3597 - val_accuracy: 0.8703
# Epoch 40/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.6401 - accuracy: 0.6520 - val_loss: 0.6098 - val_accuracy: 0.6543
# Epoch 41/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.5634 - accuracy: 0.6952 - val_loss: 0.5518 - val_accuracy: 0.7048
# Epoch 42/50
# 32/32 [==============================] - 432s 14s/step - loss: 0.4963 - accuracy: 0.7473 - val_loss: 0.5043 - val_accuracy: 0.7437
# Epoch 43/50
# 32/32 [==============================] - 445s 14s/step - loss: 0.4347 - accuracy: 0.7878 - val_loss: 0.4610 - val_accuracy: 0.7771
# Epoch 44/50
# 32/32 [==============================] - 435s 14s/step - loss: 0.3711 - accuracy: 0.8264 - val_loss: 0.4035 - val_accuracy: 0.8161
# Epoch 45/50
# 32/32 [==============================] - 439s 14s/step - loss: 0.3023 - accuracy: 0.8653 - val_loss: 0.3533 - val_accuracy: 0.8516
# Epoch 46/50
# 32/32 [==============================] - 437s 14s/step - loss: 0.2325 - accuracy: 0.9025 - val_loss: 0.3117 - val_accuracy: 0.8810
# Epoch 47/50
# 32/32 [==============================] - 441s 14s/step - loss: 0.1847 - accuracy: 0.9264 - val_loss: 0.2932 - val_accuracy: 0.8961
# Epoch 48/50
# 32/32 [==============================] - 434s 14s/step - loss: 0.1577 - accuracy: 0.9393 - val_loss: 0.2804 - val_accuracy: 0.9060
# Epoch 49/50
#  9/32 [=======>......................] - ETA: 5:01 - loss: 0.1398 - accuracy: 0.9464

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# !pip install yfinance
# !pip install yahooquery
from yahooquery import Screener
import yfinance as yf   
import pandas as pd
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,LSTM
from tensorflow.keras.layers import Dropout
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import NearestCentroid
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
import tensorflow as tf
from sklearn.tree import DecisionTreeClassifier
from sys import getsizeof
from datetime import datetime
from numpy import array
# Out:
# Collecting yfinance
#   Downloading yfinance-0.1.70-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Collecting requests>=2.26
#   Downloading requests-2.27.1-py2.py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.4 MB/s
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Collecting lxml>=4.5.1
#   Downloading lxml-4.8.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.4 MB)
#      |████████████████████████████████| 6.4 MB 17.6 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Installing collected packages: requests, lxml, yfinance
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.2.6
#     Uninstalling lxml-4.2.6:
#       Successfully uninstalled lxml-4.2.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.27.1 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed lxml-4.8.0 requests-2.27.1 yfinance-0.1.70
# Collecting yahooquery
#   Downloading yahooquery-2.2.15-py2.py3-none-any.whl (46 kB)
#      |████████████████████████████████| 46 kB 2.7 MB/s
# Collecting requests-futures>=1.0.0
#   Downloading requests_futures-1.0.0-py2.py3-none-any.whl (7.4 kB)
# Requirement already satisfied: lxml>=4.6.2 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.8.0)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (1.3.5)
# Requirement already satisfied: tqdm>=4.54.1 in /usr/local/lib/python3.7/dist-packages (from yahooquery) (4.64.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (1.21.5)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yahooquery) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yahooquery) (1.15.0)
# Requirement already satisfied: requests>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from requests-futures>=1.0.0->yahooquery) (2.27.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=1.2.0->requests-futures>=1.0.0->yahooquery) (1.24.3)
# Installing collected packages: requests-futures, yahooquery
# Successfully installed requests-futures-1.0.0 yahooquery-2.2.15

# %%
def read_syms_from_txt():  
  with open("syms.txt","r") as f:
    lines = f.readlines()
    f.close()
  lst = []
  for line in lines:
    line = line.strip()
    lst.append(line)
  symbols = lst
  return symbols
def get_crypto_syms():
  #'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in',
   screens = [
  'all_cryptocurrencies_au','all_cryptocurrencies_ca','all_cryptocurrencies_eu','all_cryptocurrencies_gb','all_cryptocurrencies_in','all_cryptocurrencies_us']
   s = Screener()
   symbols = []
   for i in screens:
      data = s.get_screeners(i, count=250)
      dicts = data[i]['quotes']
      syms = [d['symbol'] for d in dicts]
      for sym in syms:
        symbols.append(sym)
   #print(len(symbols))
   #pieces = 15
   # new_arrays = np.array_split(symbols, pieces)
   return symbols
def spliting(data):
  X = data.drop(["suggestion"],axis=1)
  y = data["suggestion"]
  xTrain, xTest, yTrain, yTest = train_test_split(X, y, test_size=0.1)
  print(xTrain.shape,end=" ")
  print(yTrain.shape)
  print(xTest.shape,end=" ")
  print(yTest.shape)
  return xTrain, xTest, yTrain, yTest
def extract_data(df):
    rows = []
    for each in range(12,df.shape[0]-1):
        sugg = 0
        if df[each][3] > df[each][0]:
          sugg = 1
        row = [
                df[each-12][0],
                df[each-12][1],
                df[each-12][2],
                df[each-12][3],
                df[each-12][4],
                df[each-11][0],
                df[each-11][1],
                df[each-11][2],
                df[each-11][3],
                df[each-11][4],
                df[each-10][0],
                df[each-10][1],
                df[each-10][2],
                df[each-10][3],
                df[each-10][4],
                df[each-9][0],
                df[each-9][1],
                df[each-9][2],
                df[each-9][3],
                df[each-9][4],
                df[each-8][0],
                df[each-8][1],
                df[each-8][2],
                df[each-8][3],
                df[each-8][4],
                df[each-7][0],
                df[each-7][1],
                df[each-7][2],
                df[each-7][3],
                df[each-7][4],
                df[each-6][0],
                df[each-6][1],
                df[each-6][2],
                df[each-6][3],
                df[each-6][4],
                df[each-5][0],
                df[each-5][1],
                df[each-5][2],
                df[each-5][3],
                df[each-5][4],
                df[each-4][0],
                df[each-4][1],
                df[each-4][2],
                df[each-4][3],
                df[each-4][4],
                df[each-3][0],
                df[each-3][1],
                df[each-3][2],
                df[each-3][3],
                df[each-3][4],
                df[each-2][0],
                df[each-2][1],
                df[each-2][2],
                df[each-2][3],
                df[each-2][4],
                df[each-1][0],
                df[each-1][2],
                df[each-1][1],
                df[each-1][3],
                df[each-1][4],
                sugg
        ]
        rows.append(row)
    return rows
def row_scaler(df):
  scaler = MinMaxScaler(feature_range=(1,10))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  scaled = pd.DataFrame(scaler.fit_transform(df.T).T,dtype=object)
  scaled["suggestion"] = last_column
  return scaled
def column_scaler(df):
  scaler = MinMaxScaler(feature_range=(0,1))
  last_column = df.iloc[: , -1]
  df = df.drop(columns=df.columns[-1], axis=1)
  df_scaled = scaler.fit_transform(df.to_numpy())
  df_scaled = pd.DataFrame(df_scaled)
  df_scaled["suggestion"] = last_column
  return df_scaled
def stick_dfs(dfs):
  dataframe = dfs[0]
  for i in range(1,len(dfs)):
     dataframe = pd.concat([dataframe,dfs[i]], ignore_index = True)
  dataframe = dataframe.dropna()
  dataframe = dataframe.astype(float)
  return dataframe
def process(dfs): 
   fixed_dfs = []
   for df in dfs:
      df = np.array(df)
      df = extract_data(df)
      df = pd.DataFrame(df)
      df = row_scaler(df)
      #df = column_scaler(df)
      fixed_dfs.append(df)
   df = stick_dfs(fixed_dfs)
   return df

# %%
#symbols = ["MSFT","AAPL","GOOG","TSLA","AMZN"]
#symbols = ["BTC-USD","LTC-USD","TRX-USD","XRP-USD","ETH-USD","BNB-USD","DASH-USD","VET-USD","LINK-USD","ADA-USD","DOT-USD","SOL-USD","BCH-USD","FTT-USD","FIL-USD","XMR-USD"]
#symbols = ["AAPL","MSFT","TSLA","GOOG"]
#symbols = ["BTC-USD","ETH-USD"]
#symbols = ["BTC-USD"]

symbols = get_crypto_syms()
#symbols = read_syms_from_txt()
dfs = []
for symbol in symbols:
           data = yf.download(symbol,period="MAX",interval="1d",progress=False)
           if data.empty :
             print("Passing...")
           else:
               dfs.append(data)
ndfs = dfs
dfs = []
for df in ndfs:
        if df.shape[0] > 13:
          dfs.append(df)

data = process(dfs)
xTrain, xTest, yTrain, yTest = spliting(data)
data
# Out:
# 1 Failed download:
# - XNO-CAD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - OXEN-CAD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VAL-CAD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ICP-EUR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - XNO-EUR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - OXEN-EUR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VAL-EUR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ICP-GBP: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - XNO-GBP: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - OXEN-GBP: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VAL-GBP: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ICP-INR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - XNO-INR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - OXEN-INR: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - VAL-INR: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WTRX-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ICP-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - BTT2-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - XCN1-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GMT3-USD: No data found, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - GLMR-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - ASTR-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - WVLX-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - DESO-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - EVER-USD: No data found for this date range, symbol may be delisted
# Passing...
#
# 1 Failed download:
# - 1ECO-USD: No data found for this date range, symbol may be delisted
# Passing...
# (1592700, 60) (1592700,)
# (176967, 60) (176967,)
#                  0          1         2         3         4         5  \
# 0         9.706879  10.000000  8.875120  9.455215  9.455215  9.401446
# 1        10.000000   9.987671  4.566510  5.944161  5.944161  5.903536
# 2         6.625815   7.307172  1.146930  2.896621  2.896621  2.879508
# 3         2.879508   6.861783  2.213081  4.859447  4.859447  4.745500
# 4         4.950069   5.530511  2.957227  3.657653  3.657653  3.694922
# ...            ...        ...       ...       ...       ...       ...
# 1769662   6.421697   8.116731  5.988977  7.235217  7.235217  7.239544
# 1769663   7.239544   7.407686  6.038740  7.351123  7.351123  7.340306
# 1769664   7.340306   9.326189  7.229653  8.340820  8.340820  8.336803
# 1769665   8.336803  10.000000  7.392851  7.905318  7.905318  7.900062
# 1769666   9.951881  10.000000  7.413564  8.893646  8.893646  8.880413
#
#                  6         7         8         9  ...        51        52  \
# 0         9.389876  4.302419  5.595268  5.595268  ...  4.718768  3.646289
# 1         6.497416  1.128067  2.653120  2.653120  ...  4.317629  1.047474
# 2         6.861783  2.213081  4.859447  4.859447  ...  2.759913  1.000000
# 3         5.349456  2.671929  3.400729  3.400729  ...  3.440285  1.140889
# 4         4.928180  3.491203  4.465726  4.465726  ...  4.304841  2.436078
# ...            ...       ...       ...       ...  ...       ...       ...
# 1769662   7.407686  6.038740  7.351123  7.351123  ...  3.735730  3.243973
# 1769663   9.326189  7.229653  8.340820  8.340820  ...  3.490625  1.000000
# 1769664  10.000000  7.392851  7.905318  7.905318  ...  3.296518  1.074183
# 1769665   7.937153  5.943541  7.084381  7.084381  ...  3.597877  2.730270
# 1769666   8.990288  7.696666  7.834210  7.834210  ...  4.399261  3.100029
#
#                53        54        55        56        57        58        59  \
# 0        3.895306  3.895306  3.889629  1.000000  4.068858  1.455729  1.455729
# 1        1.533096  1.533096  1.501734  1.000000  2.533964  1.438175  1.438175
# 2        1.502717  1.502717  1.591258  1.140889  3.440285  2.981205  2.981205
# 3        2.981205  2.981205  3.049874  2.129668  4.074134  2.470487  2.470487
# 4        2.763627  2.763627  2.814560  1.000000  2.685568  1.305905  1.305905
# ...           ...       ...       ...       ...       ...       ...       ...
# 1769662  3.243973  3.243973  3.248918  1.000000  3.490625  1.077273  1.077273
# 1769663  1.077273  1.077273  1.074183  1.074183  3.296518  2.758706  2.758706
# 1769664  2.758706  2.758706  2.759015  2.730270  3.597877  3.333917  3.333917
# 1769665  3.333917  3.333917  3.330209  2.618691  3.620132  2.947867  2.947867
# 1769666  3.527089  3.527089  3.529097  3.109252  3.697114  3.566389  3.566389
#
#          suggestion
# 0               0.0
# 1               1.0
# 2               0.0
# 3               0.0
# 4               0.0
# ...             ...
# 1769662         1.0
# 1769663         1.0
# 1769664         0.0
# 1769665         1.0
# 1769666         0.0
#
# [1769667 rows x 61 columns]

# %%
model = Sequential()


model.add(Dense(5000, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dense(2500, activation='relu'))
model.add(Dense(2000, activation='relu'))
model.add(Dense(1000, activation='relu'))
model.add(Dense(500, activation='relu'))
model.add(Dense(250, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer="adam", loss='binary_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 5000)              305000
#
#  dense_1 (Dense)             (None, 2500)              12502500
#
#  dense_2 (Dense)             (None, 2000)              5002000
#
#  dense_3 (Dense)             (None, 1000)              2001000
#
#  dense_4 (Dense)             (None, 500)               500500
#
#  dense_5 (Dense)             (None, 250)               125250
#
#  dense_6 (Dense)             (None, 100)               25100
#
#  dense_7 (Dense)             (None, 1)                 101
#
# =================================================================
# Total params: 20,461,451
# Trainable params: 20,461,451
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(xTrain,yTrain,epochs=75,batch_size=10000,validation_data=(xTest,yTest))
# Out:
# Epoch 1/75
# 160/160 [==============================] - 53s 331ms/step - loss: 0.6866 - accuracy: 0.5449 - val_loss: 0.6830 - val_accuracy: 0.5560
# Epoch 2/75
# 160/160 [==============================] - 54s 341ms/step - loss: 0.6822 - accuracy: 0.5571 - val_loss: 0.6785 - val_accuracy: 0.5660
# Epoch 3/75
# 160/160 [==============================] - 55s 343ms/step - loss: 0.6790 - accuracy: 0.5629 - val_loss: 0.6759 - val_accuracy: 0.5690
# Epoch 4/75
# 160/160 [==============================] - 55s 342ms/step - loss: 0.6737 - accuracy: 0.5728 - val_loss: 0.6716 - val_accuracy: 0.5757
# Epoch 5/75
# 160/160 [==============================] - 55s 342ms/step - loss: 0.6618 - accuracy: 0.5898 - val_loss: 0.6537 - val_accuracy: 0.5980
# Epoch 6/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.6444 - accuracy: 0.6104 - val_loss: 0.6405 - val_accuracy: 0.6141
# Epoch 7/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.6234 - accuracy: 0.6324 - val_loss: 0.6164 - val_accuracy: 0.6384
# Epoch 8/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.5976 - accuracy: 0.6567 - val_loss: 0.5976 - val_accuracy: 0.6589
# Epoch 9/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.5645 - accuracy: 0.6873 - val_loss: 0.5744 - val_accuracy: 0.6803
# Epoch 10/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.5184 - accuracy: 0.7266 - val_loss: 0.5220 - val_accuracy: 0.7260
# Epoch 11/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.4561 - accuracy: 0.7736 - val_loss: 0.4732 - val_accuracy: 0.7688
# Epoch 12/75
# 160/160 [==============================] - 54s 341ms/step - loss: 0.3854 - accuracy: 0.8205 - val_loss: 0.4106 - val_accuracy: 0.8119
# Epoch 13/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.3119 - accuracy: 0.8640 - val_loss: 0.3540 - val_accuracy: 0.8497
# Epoch 14/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.2495 - accuracy: 0.8976 - val_loss: 0.3098 - val_accuracy: 0.8758
# Epoch 15/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.2066 - accuracy: 0.9187 - val_loss: 0.3014 - val_accuracy: 0.8857
# Epoch 16/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.1728 - accuracy: 0.9343 - val_loss: 0.2667 - val_accuracy: 0.9021
# Epoch 17/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.1450 - accuracy: 0.9462 - val_loss: 0.2498 - val_accuracy: 0.9141
# Epoch 18/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.1269 - accuracy: 0.9536 - val_loss: 0.2464 - val_accuracy: 0.9191
# Epoch 19/75
# 160/160 [==============================] - 55s 342ms/step - loss: 0.1112 - accuracy: 0.9598 - val_loss: 0.2484 - val_accuracy: 0.9183
# Epoch 20/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0995 - accuracy: 0.9640 - val_loss: 0.2373 - val_accuracy: 0.9268
# Epoch 21/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0933 - accuracy: 0.9661 - val_loss: 0.2425 - val_accuracy: 0.9282
# Epoch 22/75
# 160/160 [==============================] - 54s 341ms/step - loss: 0.0844 - accuracy: 0.9692 - val_loss: 0.2335 - val_accuracy: 0.9320
# Epoch 23/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.0814 - accuracy: 0.9699 - val_loss: 0.2522 - val_accuracy: 0.9270
# Epoch 24/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0766 - accuracy: 0.9715 - val_loss: 0.2487 - val_accuracy: 0.9308
# Epoch 25/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0727 - accuracy: 0.9729 - val_loss: 0.2465 - val_accuracy: 0.9324
# Epoch 26/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0673 - accuracy: 0.9747 - val_loss: 0.2513 - val_accuracy: 0.9332
# Epoch 27/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0655 - accuracy: 0.9752 - val_loss: 0.2467 - val_accuracy: 0.9347
# Epoch 28/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.0621 - accuracy: 0.9763 - val_loss: 0.2567 - val_accuracy: 0.9343
# Epoch 29/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0615 - accuracy: 0.9763 - val_loss: 0.2519 - val_accuracy: 0.9356
# Epoch 30/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0579 - accuracy: 0.9776 - val_loss: 0.2591 - val_accuracy: 0.9340
# Epoch 31/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0573 - accuracy: 0.9776 - val_loss: 0.2577 - val_accuracy: 0.9375
# Epoch 32/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0550 - accuracy: 0.9785 - val_loss: 0.2488 - val_accuracy: 0.9390
# Epoch 33/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0552 - accuracy: 0.9782 - val_loss: 0.2602 - val_accuracy: 0.9389
# Epoch 34/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0523 - accuracy: 0.9794 - val_loss: 0.2648 - val_accuracy: 0.9384
# Epoch 35/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.0516 - accuracy: 0.9797 - val_loss: 0.2675 - val_accuracy: 0.9395
# Epoch 36/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0515 - accuracy: 0.9796 - val_loss: 0.2665 - val_accuracy: 0.9375
# Epoch 37/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0509 - accuracy: 0.9797 - val_loss: 0.2593 - val_accuracy: 0.9365
# Epoch 38/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0504 - accuracy: 0.9799 - val_loss: 0.2589 - val_accuracy: 0.9404
# Epoch 39/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0480 - accuracy: 0.9808 - val_loss: 0.2576 - val_accuracy: 0.9413
# Epoch 40/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0500 - accuracy: 0.9800 - val_loss: 0.2781 - val_accuracy: 0.9183
# Epoch 41/75
# 160/160 [==============================] - 54s 341ms/step - loss: 0.0548 - accuracy: 0.9781 - val_loss: 0.2663 - val_accuracy: 0.9398
# Epoch 42/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0443 - accuracy: 0.9820 - val_loss: 0.2729 - val_accuracy: 0.9404
# Epoch 43/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0436 - accuracy: 0.9823 - val_loss: 0.2715 - val_accuracy: 0.9409
# Epoch 44/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0428 - accuracy: 0.9826 - val_loss: 0.2742 - val_accuracy: 0.9416
# Epoch 45/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.0445 - accuracy: 0.9820 - val_loss: 0.2662 - val_accuracy: 0.9404
# Epoch 46/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0447 - accuracy: 0.9819 - val_loss: 0.2719 - val_accuracy: 0.9424
# Epoch 47/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0423 - accuracy: 0.9827 - val_loss: 0.2718 - val_accuracy: 0.9411
# Epoch 48/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0420 - accuracy: 0.9829 - val_loss: 0.2656 - val_accuracy: 0.9395
# Epoch 49/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0425 - accuracy: 0.9827 - val_loss: 0.2675 - val_accuracy: 0.9398
# Epoch 50/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0414 - accuracy: 0.9831 - val_loss: 0.2778 - val_accuracy: 0.9425
# Epoch 51/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.0427 - accuracy: 0.9826 - val_loss: 0.2744 - val_accuracy: 0.9397
# Epoch 52/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0408 - accuracy: 0.9833 - val_loss: 0.2804 - val_accuracy: 0.9401
# Epoch 53/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0406 - accuracy: 0.9834 - val_loss: 0.2819 - val_accuracy: 0.9390
# Epoch 54/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0405 - accuracy: 0.9834 - val_loss: 0.2804 - val_accuracy: 0.9401
# Epoch 55/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0414 - accuracy: 0.9831 - val_loss: 0.2756 - val_accuracy: 0.9404
# Epoch 56/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.0397 - accuracy: 0.9837 - val_loss: 0.2850 - val_accuracy: 0.9428
# Epoch 57/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0394 - accuracy: 0.9838 - val_loss: 0.2716 - val_accuracy: 0.9420
# Epoch 58/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0377 - accuracy: 0.9844 - val_loss: 0.2936 - val_accuracy: 0.9416
# Epoch 59/75
# 160/160 [==============================] - 54s 338ms/step - loss: 0.0384 - accuracy: 0.9843 - val_loss: 0.2777 - val_accuracy: 0.9411
# Epoch 60/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0385 - accuracy: 0.9841 - val_loss: 0.2800 - val_accuracy: 0.9419
# Epoch 61/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0378 - accuracy: 0.9844 - val_loss: 0.2735 - val_accuracy: 0.9416
# Epoch 62/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0382 - accuracy: 0.9843 - val_loss: 0.2746 - val_accuracy: 0.9429
# Epoch 63/75
# 160/160 [==============================] - 54s 341ms/step - loss: 0.0373 - accuracy: 0.9846 - val_loss: 0.2809 - val_accuracy: 0.9431
# Epoch 64/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0376 - accuracy: 0.9845 - val_loss: 0.2787 - val_accuracy: 0.9437
# Epoch 65/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0373 - accuracy: 0.9846 - val_loss: 0.2734 - val_accuracy: 0.9404
# Epoch 66/75
# 160/160 [==============================] - 54s 338ms/step - loss: 0.0379 - accuracy: 0.9845 - val_loss: 0.2752 - val_accuracy: 0.9423
# Epoch 67/75
# 160/160 [==============================] - 54s 339ms/step - loss: 0.0364 - accuracy: 0.9849 - val_loss: 0.2788 - val_accuracy: 0.9414
# Epoch 68/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0356 - accuracy: 0.9853 - val_loss: 0.2799 - val_accuracy: 0.9420
# Epoch 69/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0355 - accuracy: 0.9853 - val_loss: 0.2795 - val_accuracy: 0.9435
# Epoch 70/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0349 - accuracy: 0.9855 - val_loss: 0.2739 - val_accuracy: 0.9442
# Epoch 71/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0346 - accuracy: 0.9857 - val_loss: 0.2811 - val_accuracy: 0.9436
# Epoch 72/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0370 - accuracy: 0.9847 - val_loss: 0.2640 - val_accuracy: 0.9425
# Epoch 73/75
# 160/160 [==============================] - 54s 341ms/step - loss: 0.0349 - accuracy: 0.9855 - val_loss: 0.2870 - val_accuracy: 0.9432
# Epoch 74/75
# 160/160 [==============================] - 55s 341ms/step - loss: 0.0342 - accuracy: 0.9858 - val_loss: 0.2756 - val_accuracy: 0.9439
# Epoch 75/75
# 160/160 [==============================] - 54s 340ms/step - loss: 0.0355 - accuracy: 0.9853 - val_loss: 0.2861 - val_accuracy: 0.9421

# %%
model.save("9421_BinaryTest_v08.h5")

# %%
from google.colab import drive
drive.mount("/content/drive")

data = pd.read_csv("/content/drive/MyDrive/BinaryTest_v08.csv")
data = data.drop("Unnamed: 0",axis=1)
xTrain, xTest, yTrain, yTest = spliting(data)
data
# Out:
# Mounted at /content/drive
# (1592700, 60) (1592700,)
# (176967, 60) (176967,)
#                  0          1         2         3         4         5  \
# 0         9.706879  10.000000  8.875120  9.455215  9.455215  9.401446
# 1        10.000000   9.987671  4.566510  5.944161  5.944161  5.903536
# 2         6.625815   7.307172  1.146930  2.896621  2.896621  2.879508
# 3         2.879508   6.861783  2.213081  4.859447  4.859447  4.745500
# 4         4.950069   5.530511  2.957227  3.657653  3.657653  3.694922
# ...            ...        ...       ...       ...       ...       ...
# 1769662   6.421697   8.116731  5.988977  7.235217  7.235217  7.239544
# 1769663   7.239544   7.407686  6.038740  7.351123  7.351123  7.340306
# 1769664   7.340306   9.326189  7.229653  8.340820  8.340820  8.336803
# 1769665   8.336803  10.000000  7.392851  7.905318  7.905318  7.900062
# 1769666   9.951881  10.000000  7.413564  8.893646  8.893646  8.880413
#
#                  6         7         8         9  ...        51        52  \
# 0         9.389876  4.302419  5.595268  5.595268  ...  4.718768  3.646289
# 1         6.497416  1.128067  2.653120  2.653120  ...  4.317629  1.047474
# 2         6.861783  2.213081  4.859447  4.859447  ...  2.759913  1.000000
# 3         5.349456  2.671929  3.400729  3.400729  ...  3.440285  1.140889
# 4         4.928180  3.491203  4.465726  4.465726  ...  4.304841  2.436078
# ...            ...       ...       ...       ...  ...       ...       ...
# 1769662   7.407686  6.038740  7.351123  7.351123  ...  3.735730  3.243973
# 1769663   9.326189  7.229653  8.340820  8.340820  ...  3.490625  1.000000
# 1769664  10.000000  7.392851  7.905318  7.905318  ...  3.296518  1.074183
# 1769665   7.937153  5.943541  7.084381  7.084381  ...  3.597877  2.730270
# 1769666   8.990288  7.696666  7.834210  7.834210  ...  4.399261  3.100029
#
#                53        54        55        56        57        58        59  \
# 0        3.895306  3.895306  3.889629  1.000000  4.068858  1.455729  1.455729
# 1        1.533096  1.533096  1.501734  1.000000  2.533964  1.438175  1.438175
# 2        1.502717  1.502717  1.591258  1.140889  3.440285  2.981205  2.981205
# 3        2.981205  2.981205  3.049874  2.129668  4.074134  2.470487  2.470487
# 4        2.763627  2.763627  2.814560  1.000000  2.685568  1.305905  1.305905
# ...           ...       ...       ...       ...       ...       ...       ...
# 1769662  3.243973  3.243973  3.248918  1.000000  3.490625  1.077273  1.077273
# 1769663  1.077273  1.077273  1.074183  1.074183  3.296518  2.758706  2.758706
# 1769664  2.758706  2.758706  2.759015  2.730270  3.597877  3.333917  3.333917
# 1769665  3.333917  3.333917  3.330209  2.618691  3.620132  2.947867  2.947867
# 1769666  3.527089  3.527089  3.529097  3.109252  3.697114  3.566389  3.566389
#
#          suggestion
# 0               0.0
# 1               1.0
# 2               0.0
# 3               0.0
# 4               0.0
# ...             ...
# 1769662         1.0
# 1769663         1.0
# 1769664         0.0
# 1769665         1.0
# 1769666         0.0
#
# [1769667 rows x 61 columns]

# %%
from google.colab import drive
drive.mount("/content/drive")

data.to_csv("BinaryTest_v08.csv")
# Out:
# Mounted at /content/drive
